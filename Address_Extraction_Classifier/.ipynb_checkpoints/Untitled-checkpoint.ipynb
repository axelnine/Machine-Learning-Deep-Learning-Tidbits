# %%
# gensim modules
from gensim import utils
from gensim.models.doc2vec import LabeledSentence, TaggedDocument
from gensim.models import Doc2Vec
import pandas as pd
# numpy
import numpy

# shuffle
from random import shuffle

# logging
import logging
import os.path
import sys
import cloudpickle as pickle

# %%
program = os.path.basename(sys.argv[0])
logger = logging.getLogger(program)
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s')
logging.root.setLevel(level=logging.INFO)
logger.info("running %s" % ' '.join(sys.argv))
# Out:
# 2019-04-07 11:32:53,512 : INFO : running C:\Anaconda3\lib\site-packages\ipykernel_launcher.py -f C:\Users\Prem Shah\AppData\Roaming\jupyter\runtime\kernel-fdfb5fa2-21bf-4641-a044-c4dde0c3c863.json

# %%
data = pd.read_csv('Data.csv')
print("******************")
print(len(data))
data.head()
# Out:
# ******************
# 11249
#                                            Text      Tag
# 0            7710 Tower Street Hamden, CT 06514  Address
# 1            932 Bishop St. Billerica, MA 01821  Address
# 2      7906 Silver Spear Road Davison, MI 48423  Address
# 3       9739 Acacia Lane Beaver Falls, PA 15010  Address
# 4  712 Oak Valley Street Temple Hills, MD 20748  Address

# %%
sentences= []
for elem in data.iterrows():
    tup = elem[1]
    ids = tup['Tag']
    #a = str(tup['Text']).split(' ')
    #t = [x.replace('}', '').replace('(', '').replace('.', ' ').replace(')', '').replace('{', '').replace(';', '').replace('-', '').replace('_', ' ') for x in a if(x != '')]
    #sentences.append(LabeledSentence(t, ids))
    #if(len(sentences)%500 == 0):
    #    print(len(sentences))
# Out:
# Text    7710 Tower Street Hamden, CT 06514
# Tag                                Address
# Name: 0, dtype: object
# Text    932 Bishop St. Billerica, MA 01821
# Tag                                Address
# Name: 1, dtype: object
# Text    7906 Silver Spear Road Davison, MI 48423
# Tag                                      Address
# Name: 2, dtype: object
# Text    9739 Acacia Lane Beaver Falls, PA 15010
# Tag                                     Address
# Name: 3, dtype: object
# Text    712 Oak Valley Street Temple Hills, MD 20748
# Tag                                          Address
# Name: 4, dtype: object
# Text    8940 Queen Ave. Scarsdale, NY 10583
# Tag                                 Address
# Name: 5, dtype: object
# Text    8262 Hartford St. Valley Stream, NY 11580
# Tag                                       Address
# Name: 6, dtype: object
# Text    51 Cross Dr. Ridgefield, CT 06877
# Tag                               Address
# Name: 7, dtype: object
# Text    43 Mill Pond St. Parsippany, NJ 07054
# Tag                                   Address
# Name: 8, dtype: object
# Text    40 Canterbury Road Belmont, MA 02478
# Tag                                  Address
# Name: 9, dtype: object
# Text    9263 Oxford Ave. Kansas City, MO 64151
# Tag                                    Address
# Name: 10, dtype: object
# Text    8564 Jackson Street Pearl, MS 39208
# Tag                                 Address
# Name: 11, dtype: object
# Text    845 W. Third St. Ridgecrest, CA 93555
# Tag                                   Address
# Name: 12, dtype: object
# Text    265 Lafayette St. Sterling Heights, MI 48310
# Tag                                          Address
# Name: 13, dtype: object
# Text    5 Cooper Street Rockledge, FL 32955
# Tag                                 Address
# Name: 14, dtype: object
# Text    7187 Del Monte Avenue Cumming, GA 30040
# Tag                                     Address
# Name: 15, dtype: object
# Text    283B Second Court Beckley, WV 25801
# Tag                                 Address
# Name: 16, dtype: object
# Text    78 W. Hilltop Drive Longwood, FL 32779
# Tag                                    Address
# Name: 17, dtype: object
# Text    416 W. Mulberry Ave. Pottstown, PA 19464
# Tag                                      Address
# Name: 18, dtype: object
# Text    984 Westminster Street Ladson, SC 29456
# Tag                                     Address
# Name: 19, dtype: object
# Text    546 James Ave. Andover, MA 01810
# Tag                              Address
# Name: 20, dtype: object
# Text    13 Cobblestone Road Yuma, AZ 85365
# Tag                                Address
# Name: 21, dtype: object
# Text    8814 Wakehurst Road Land O Lakes, FL 34639
# Tag                                        Address
# Name: 22, dtype: object
# Text    2 Indian Spring Street Blackwood, NJ 08012
# Tag                                        Address
# Name: 23, dtype: object
# Text    9303 Clark Drive Dawsonville, GA 30534
# Tag                                    Address
# Name: 24, dtype: object
# Text    8246 West Cottage Street Alpharetta, GA 30004
# Tag                                           Address
# Name: 25, dtype: object
# Text    69 Meadow Ave. Logansport, IN 46947
# Tag                                 Address
# Name: 26, dtype: object
# Text    615 Windsor St. Reading, MA 01867
# Tag                               Address
# Name: 27, dtype: object
# Text    9487 W. Kirkland Ave. New Lenox, IL 60451
# Tag                                       Address
# Name: 28, dtype: object
# Text    70 Plymouth St. Chaska, MN 55318
# Tag                              Address
# Name: 29, dtype: object
# Text    9892 Arrowhead Street Mcminnville, TN 37110
# Tag                                         Address
# Name: 30, dtype: object
# Text    9915 Nut Swamp Road Encino, CA 91316
# Tag                                  Address
# Name: 31, dtype: object
# Text    656 Holly Drive Taylors, SC 29687
# Tag                               Address
# Name: 32, dtype: object
# Text    165 Saxton St. Glastonbury, CT 06033
# Tag                                  Address
# Name: 33, dtype: object
# Text    23 Oak Valley St. Westport, CT 06880
# Tag                                  Address
# Name: 34, dtype: object
# Text    596 Livingston Street Barrington, IL 60010
# Tag                                        Address
# Name: 35, dtype: object
# Text    8829 Cherry Ave. Saint Augustine, FL 32084
# Tag                                        Address
# Name: 36, dtype: object
# Text    83 Sage Drive Westbury, NY 11590
# Tag                              Address
# Name: 37, dtype: object
# Text    7981 Wild Horse Street Northville, MI 48167
# Tag                                         Address
# Name: 38, dtype: object
# Text    992 Hilldale Ave. Ellicott City, MD 21042
# Tag                                       Address
# Name: 39, dtype: object
# Text    703 East Livingston Lane Ft Mitchell, KY 41017
# Tag                                            Address
# Name: 40, dtype: object
# Text    39 Atlantic Lane Wappingers Falls, NY 12590
# Tag                                         Address
# Name: 41, dtype: object
# Text    3 College Court Calumet City, IL 60409
# Tag                                    Address
# Name: 42, dtype: object
# Text    720 Wilson Street Wilson, NC 27893
# Tag                                Address
# Name: 43, dtype: object
# Text    63 W. Hillside St. Perrysburg, OH 43551
# Tag                                     Address
# Name: 44, dtype: object
# Text    70 Green Hill Circle Peabody, MA 01960
# Tag                                    Address
# Name: 45, dtype: object
# Text    50 Woodside Court Coram, NY 11727
# Tag                               Address
# Name: 46, dtype: object
# Text    431 South Spring St. Monroe, NY 10950
# Tag                                   Address
# Name: 47, dtype: object
# Text    7518 Cooper Street Fort Walton Beach, FL 32547
# Tag                                            Address
# Name: 48, dtype: object
# Text    267 Laurel Ave. Bethlehem, PA 18015
# Tag                                 Address
# Name: 49, dtype: object
# Text    2 Marshall Lane Lake In The Hills, IL 60156
# Tag                                         Address
# Name: 50, dtype: object
# Text    53 Marconi Lane Clifton, NJ 07011
# Tag                               Address
# Name: 51, dtype: object
# Text    711 Wrangler Ave. Yonkers, NY 10701
# Tag                                 Address
# Name: 52, dtype: object
# Text    587 Howard Ave. Starkville, MS 39759
# Tag                                  Address
# Name: 53, dtype: object
# Text    8654 Shore Ave. Westwood, NJ 07675
# Tag                                Address
# Name: 54, dtype: object
# Text    7476 Oakwood Drive Coventry, RI 02816
# Tag                                   Address
# Name: 55, dtype: object
# Text    67 Jockey Hollow Drive Manassas, VA 20109
# Tag                                       Address
# Name: 56, dtype: object
# Text    6 Carriage St. Freehold, NJ 07728
# Tag                               Address
# Name: 57, dtype: object
# Text    13 Division St. Kokomo, IN 46901
# Tag                              Address
# Name: 58, dtype: object
# Text    957 County Dr. Clermont, FL 34711
# Tag                               Address
# Name: 59, dtype: object
# Text    457 Bow Ridge St. Collierville, TN 38017
# Tag                                      Address
# Name: 60, dtype: object
# Text    258 Summit Circle Oak Creek, WI 53154
# Tag                                   Address
# Name: 61, dtype: object
# Text    8662 Cross Lane Richmond Hill, NY 11418
# Tag                                     Address
# Name: 62, dtype: object
# Text    37 New Saddle Ave. Greenfield, IN 46140
# Tag                                     Address
# Name: 63, dtype: object
# Text    7780 North Lookout Drive West Des Moines, IA 5...
# Tag                                               Address
# Name: 64, dtype: object
# Text    566 Glendale Ave. Boynton Beach, FL 33435
# Tag                                       Address
# Name: 65, dtype: object
# Text    8444A W. Rose Drive Worcester, MA 01604
# Tag                                     Address
# Name: 66, dtype: object
# Text    532 Lancaster Street Oxon Hill, MD 20745
# Tag                                      Address
# Name: 67, dtype: object
# Text    478 Wakehurst St. Olympia, WA 98512
# Tag                                 Address
# Name: 68, dtype: object
# Text    27 Ramblewood Ave. Edison, NJ 08817
# Tag                                 Address
# Name: 69, dtype: object
# Text    9484 Manchester St. Dickson, TN 37055
# Tag                                   Address
# Name: 70, dtype: object
# Text    8902 Canal Street Daphne, AL 36526
# Tag                                Address
# Name: 71, dtype: object
# Text    7931 West Westminster Street Lansing, MI 48910
# Tag                                            Address
# Name: 72, dtype: object
# Text    27 Redwood Dr. Chattanooga, TN 37421
# Tag                                  Address
# Name: 73, dtype: object
# Text    8934 Bradford Street Janesville, WI 53546
# Tag                                       Address
# Name: 74, dtype: object
# Text    83 Edgemont Ave. Glen Ellyn, IL 60137
# Tag                                   Address
# Name: 75, dtype: object
# Text    443 James Dr. Savage, MN 55378
# Tag                            Address
# Name: 76, dtype: object
# Text    24 W. Rockcrest Street Goldsboro, NC 27530
# Tag                                        Address
# Name: 77, dtype: object
# Text    34 Coffee Drive West Haven, CT 06516
# Tag                                  Address
# Name: 78, dtype: object
# Text    1 Walt Whitman St. Vienna, VA 22180
# Tag                                 Address
# Name: 79, dtype: object
# Text    64 Indian Summer Street Grandville, MI 49418
# Tag                                          Address
# Name: 80, dtype: object
# Text    875 Livingston Dr. Youngstown, OH 44512
# Tag                                     Address
# Name: 81, dtype: object
# Text    394 Lyme Ave. Philadelphia, PA 19111
# Tag                                  Address
# Name: 82, dtype: object
# Text    231 Parker Drive Fort Mill, SC 29708
# Tag                                  Address
# Name: 83, dtype: object
# Text    201 Trusel St. Commack, NY 11725
# Tag                              Address
# Name: 84, dtype: object
# Text    69 West Westport Avenue Martinsville, VA 24112
# Tag                                            Address
# Name: 85, dtype: object
# Text    216 King St. Parlin, NJ 08859
# Tag                           Address
# Name: 86, dtype: object
# Text    81 Virginia Court Honolulu, HI 96815
# Tag                                  Address
# Name: 87, dtype: object
# Text    7036 Fairground Ave. Hyattsville, MD 20782
# Tag                                        Address
# Name: 88, dtype: object
# Text    71 South Glenholme Road Woodstock, GA 30188
# Tag                                         Address
# Name: 89, dtype: object
# Text    486 W. Augusta St. Hillsboro, OR 97124
# Tag                                    Address
# Name: 90, dtype: object
# Text    8351 Winding Way Road Annapolis, MD 21401
# Tag                                       Address
# Name: 91, dtype: object
# Text    624 Lafayette Ave. Woonsocket, RI 02895
# Tag                                     Address
# Name: 92, dtype: object
# Text    8217 Honey Creek Street Sidney, OH 45365
# Tag                                      Address
# Name: 93, dtype: object
# Text    89 South Ave. Riverdale, GA 30274
# Tag                               Address
# Name: 94, dtype: object
# Text    675 Marlborough Street Sugar Land, TX 77478
# Tag                                         Address
# Name: 95, dtype: object
# Text    7993 Applegate Drive Silver Spring, MD 20901
# Tag                                          Address
# Name: 96, dtype: object
# Text    8093 Fawn Street Orange, NJ 07050
# Tag                               Address
# Name: 97, dtype: object
# Text    318 Rock Creek Street La Vergne, TN 37086
# Tag                                       Address
# Name: 98, dtype: object
# Text    8 Bald Hill St. La Crosse, WI 54601
# Tag                                 Address
# Name: 99, dtype: object
# Text    835 Glenlake Drive Oak Park, MI 48237
# Tag                                   Address
# Name: 100, dtype: object
# Text    728 Oakland St. Bel Air, MD 21014
# Tag                               Address
# Name: 101, dtype: object
# Text    388 West Magnolia Rd. Knoxville, TN 37918
# Tag                                       Address
# Name: 102, dtype: object
# Text    9593 E. Myrtle St. Superior, WI 54880
# Tag                                   Address
# Name: 103, dtype: object
# Text    9580 Grand Street Waynesboro, PA 17268
# Tag                                    Address
# Name: 104, dtype: object
# Text    35 Birch Hill Street Yorktown Heights, NY 10598
# Tag                                             Address
# Name: 105, dtype: object
# Text    47 East Mountainview Road Amarillo, TX 79106
# Tag                                          Address
# Name: 106, dtype: object
# Text    210 1st Street Midlothian, VA 23112
# Tag                                 Address
# Name: 107, dtype: object
# Text    274 4th Court Sun Prairie, WI 53590
# Tag                                 Address
# Name: 108, dtype: object
# Text    419 Whitemarsh Street Canton, GA 30114
# Tag                                    Address
# Name: 109, dtype: object
# Text    379 Gates Dr. Selden, NY 11784
# Tag                            Address
# Name: 110, dtype: object
# Text    718 Liberty Court Rock Hill, SC 29730
# Tag                                   Address
# Name: 111, dtype: object
# Text    70 South Holly Court Grovetown, GA 30813
# Tag                                      Address
# Name: 112, dtype: object
# Text    5 Amherst Drive Allen Park, MI 48101
# Tag                                  Address
# Name: 113, dtype: object
# Text    316 Columbia St. New Albany, IN 47150
# Tag                                   Address
# Name: 114, dtype: object
# Text    9 Myrtle Road Lake Charles, LA 70605
# Tag                                  Address
# Name: 115, dtype: object
# Text    408 W. Marshall Court Newburgh, NY 12550
# Tag                                      Address
# Name: 116, dtype: object
# Text    72 Hilltop St. Waterbury, CT 06705
# Tag                                Address
# Name: 117, dtype: object
# Text    50 Airport Rd. Wausau, WI 54401
# Tag                             Address
# Name: 118, dtype: object
# Text    4 4th Court Easley, SC 29640
# Tag                          Address
# Name: 119, dtype: object
# Text    117 Center Street Delray Beach, FL 33445
# Tag                                      Address
# Name: 120, dtype: object
# Text    9104 Atlantic Drive Lexington, NC 27292
# Tag                                     Address
# Name: 121, dtype: object
# Text    89 W. Bedford Road Upper Darby, PA 19082
# Tag                                      Address
# Name: 122, dtype: object
# Text    815 S. Walnut Drive Germantown, MD 20874
# Tag                                      Address
# Name: 123, dtype: object
# Text    148 4th Avenue Asbury Park, NJ 07712
# Tag                                  Address
# Name: 124, dtype: object
# Text    67 Buttonwood Drive Fremont, OH 43420
# Tag                                   Address
# Name: 125, dtype: object
# Text    32 College Street Levittown, NY 11756
# Tag                                   Address
# Name: 126, dtype: object
# Text    585 Bridle Ave. Snellville, GA 30039
# Tag                                  Address
# Name: 127, dtype: object
# Text    95 Nut Swamp Dr. Jamaica, NY 11432
# Tag                                Address
# Name: 128, dtype: object
# Text    3 Heather Lane Desoto, TX 75115
# Tag                             Address
# Name: 129, dtype: object
# Text    7989 Homewood Dr. Winder, GA 30680
# Tag                                Address
# Name: 130, dtype: object
# Text    9708 North Shub Farm Street Coatesville, PA 19320
# Tag                                               Address
# Name: 131, dtype: object
# Text    71 Grove Dr. San Diego, CA 92111
# Tag                              Address
# Name: 132, dtype: object
# Text    8006 Lake Forest Drive Tiffin, OH 44883
# Tag                                     Address
# Name: 133, dtype: object
# Text    44 Yukon St. Altoona, PA 16601
# Tag                            Address
# Name: 134, dtype: object
# Text    321 Wilson Ave. Holyoke, MA 01040
# Tag                               Address
# Name: 135, dtype: object
# Text    278 Manhattan Court Englewood, NJ 07631
# Tag                                     Address
# Name: 136, dtype: object
# Text    8688 Highland St. Rocklin, CA 95677
# Tag                                 Address
# Name: 137, dtype: object
# Text    7828 Green Street Lebanon, PA 17042
# Tag                                 Address
# Name: 138, dtype: object
# Text    64 Princeton Street Dedham, MA 02026
# Tag                                  Address
# Name: 139, dtype: object
# Text    7758 Greystone St. Mankato, MN 56001
# Tag                                  Address
# Name: 140, dtype: object
# Text    14 Livingston St. Hartselle, AL 35640
# Tag                                   Address
# Name: 141, dtype: object
# Text    76 N. Griffin St. Riverside, NJ 08075
# Tag                                   Address
# Name: 142, dtype: object
# Text    7127 Heritage Lane Peoria, IL 61604
# Tag                                 Address
# Name: 143, dtype: object
# Text    72 Corona Rd. Newark, NJ 07103
# Tag                            Address
# Name: 144, dtype: object
# Text    7587 Lincoln Avenue Mcdonough, GA 30252
# Tag                                     Address
# Name: 145, dtype: object
# Text    4 Homestead Street Greensburg, PA 15601
# Tag                                     Address
# Name: 146, dtype: object
# Text    271 N. Marlborough Ave. Southampton, PA 18966
# Tag                                           Address
# Name: 147, dtype: object
# Text    133 Rockaway Court Essex, MD 21221
# Tag                                Address
# Name: 148, dtype: object
# Text    9706 Halifax Road Lawrence Township, NJ 08648
# Tag                                           Address
# Name: 149, dtype: object
# Text    955 East Wall Rd. Grand Blanc, MI 48439
# Tag                                     Address
# Name: 150, dtype: object
# Text    587 Bay Meadows Ave. Deerfield, IL 60015
# Tag                                      Address
# Name: 151, dtype: object
# Text    811 Walnut Street Lumberton, NC 28358
# Tag                                   Address
# Name: 152, dtype: object
# Text    11 Grand Drive Port Saint Lucie, FL 34952
# Tag                                       Address
# Name: 153, dtype: object
# Text    981 Jones St. New Port Richey, FL 34653
# Tag                                     Address
# Name: 154, dtype: object
# Text    614 High Noon Lane Taunton, MA 02780
# Tag                                  Address
# Name: 155, dtype: object
# Text    200 Bishop Drive Burnsville, MN 55337
# Tag                                   Address
# Name: 156, dtype: object
# Text    485 Wilson Lane Mc Lean, VA 22101
# Tag                               Address
# Name: 157, dtype: object
# Text    7 SW. Ohio Lane Northbrook, IL 60062
# Tag                                  Address
# Name: 158, dtype: object
# Text    8376 Summit Lane Phillipsburg, NJ 08865
# Tag                                     Address
# Name: 159, dtype: object
# Text    985 Princeton Dr. Bonita Springs, FL 34135
# Tag                                        Address
# Name: 160, dtype: object
# Text    8 Pacific Drive Staten Island, NY 10301
# Tag                                     Address
# Name: 161, dtype: object
# Text    8011 South Locust Ave. Bowling Green, KY 42101
# Tag                                            Address
# Name: 162, dtype: object
# Text    8204 Sherwood Court Fresh Meadows, NY 11365
# Tag                                         Address
# Name: 163, dtype: object
# Text    185 Fieldstone Lane New Castle, PA 16101
# Tag                                      Address
# Name: 164, dtype: object
# Text    8037 Carriage Lane Massapequa Park, NY 11762
# Tag                                          Address
# Name: 165, dtype: object
# Text    86 Thomas St. Lititz, PA 17543
# Tag                            Address
# Name: 166, dtype: object
# Text    9265 Olive Street Odenton, MD 21113
# Tag                                 Address
# Name: 167, dtype: object
# Text    57 San Carlos Circle Elizabethton, TN 37643
# Tag                                         Address
# Name: 168, dtype: object
# Text    82 Walnutwood Street Wheeling, WV 26003
# Tag                                     Address
# Name: 169, dtype: object
# Text    79 Kirkland Ave. Crawfordsville, IN 47933
# Tag                                       Address
# Name: 170, dtype: object
# Text    354 S. Cleveland Ave. Santa Cruz, CA 95060
# Tag                                        Address
# Name: 171, dtype: object
# Text    844 Woodsman St. Elizabeth City, NC 27909
# Tag                                       Address
# Name: 172, dtype: object
# Text    8456 Saxon Ave. Mays Landing, NJ 08330
# Tag                                    Address
# Name: 173, dtype: object
# Text    7306 2nd Street Perth Amboy, NJ 08861
# Tag                                   Address
# Name: 174, dtype: object
# Text    5 Lakewood St. Burlington, MA 01803
# Tag                                 Address
# Name: 175, dtype: object
# Text    58 Fairview Lane Vicksburg, MS 39180
# Tag                                  Address
# Name: 176, dtype: object
# Text    936 Hill Street Meriden, CT 06450
# Tag                               Address
# Name: 177, dtype: object
# Text    88 Orchard St. North Fort Myers, FL 33917
# Tag                                       Address
# Name: 178, dtype: object
# Text    23 Birch Hill Ave. Englishtown, NJ 07726
# Tag                                      Address
# Name: 179, dtype: object
# Text    885 Catherine St. Pasadena, MD 21122
# Tag                                  Address
# Name: 180, dtype: object
# Text    83 Bohemia Lane Belleville, NJ 07109
# Tag                                  Address
# Name: 181, dtype: object
# Text    158 Beacon Circle Mchenry, IL 60050
# Tag                                 Address
# Name: 182, dtype: object
# Text    262 East College Drive Spring Valley, NY 10977
# Tag                                            Address
# Name: 183, dtype: object
# Text    14 N. Race Lane Des Plaines, IL 60016
# Tag                                   Address
# Name: 184, dtype: object
# Text    9364 Fifth Rd. Mount Prospect, IL 60056
# Tag                                     Address
# Name: 185, dtype: object
# Text    33 Sussex Court Battle Creek, MI 49015
# Tag                                    Address
# Name: 186, dtype: object
# Text    26 Griffin Drive Bayonne, NJ 07002
# Tag                                Address
# Name: 187, dtype: object
# Text    8467 Edgewood Street Upper Marlboro, MD 20772
# Tag                                           Address
# Name: 188, dtype: object
# Text    603 W. Clark St. Tonawanda, NY 14150
# Tag                                  Address
# Name: 189, dtype: object
# Text    122 Rockville St. Prior Lake, MN 55372
# Tag                                    Address
# Name: 190, dtype: object
# Text    28 Rockledge Street Lynchburg, VA 24502
# Tag                                     Address
# Name: 191, dtype: object
# Text    653 Glenwood St. Wadsworth, OH 44281
# Tag                                  Address
# Name: 192, dtype: object
# Text    198 N. Mill Pond Rd. Stockbridge, GA 30281
# Tag                                        Address
# Name: 193, dtype: object
# Text    8919 E. Airport Ave. Dorchester Center, MA 02124
# Tag                                              Address
# Name: 194, dtype: object
# Text    7482 St Margarets Road Fayetteville, NC 28303
# Tag                                           Address
# Name: 195, dtype: object
# Text    7878 Blackburn Drive Kennewick, WA 99337
# Tag                                      Address
# Name: 196, dtype: object
# Text    931 Lancaster St. Muskego, WI 53150
# Tag                                 Address
# Name: 197, dtype: object
# Text    300 East Pumpkin Hill Drive Chicago Heights, I...
# Tag                                               Address
# Name: 198, dtype: object
# Text    7369 W. Smith Street Flint, MI 48504
# Tag                                  Address
# Name: 199, dtype: object
# Text    646 Winchester St. Mount Juliet, TN 37122
# Tag                                       Address
# Name: 200, dtype: object
# Text    7487 Shipley Lane New Baltimore, MI 48047
# Tag                                       Address
# Name: 201, dtype: object
# Text    433 N. Summit Drive Marcus Hook, PA 19061
# Tag                                       Address
# Name: 202, dtype: object
# Text    38 George Drive Tacoma, WA 98444
# Tag                              Address
# Name: 203, dtype: object
# Text    532 Pendergast Ave. Casselberry, FL 32707
# Tag                                       Address
# Name: 204, dtype: object
# Text    553 Bald Hill Dr. North Brunswick, NJ 08902
# Tag                                         Address
# Name: 205, dtype: object
# Text    17 Smith Store Road Sykesville, MD 21784
# Tag                                      Address
# Name: 206, dtype: object
# Text    591 Proctor Drive West Bend, WI 53095
# Tag                                   Address
# Name: 207, dtype: object
# Text    838 Wild Horse St. Lakeland, FL 33801
# Tag                                   Address
# Name: 208, dtype: object
# Text    971 Ridgeview Rd. Garfield, NJ 07026
# Tag                                  Address
# Name: 209, dtype: object
# Text    769 Sleepy Hollow Lane Muncie, IN 47302
# Tag                                     Address
# Name: 210, dtype: object
# Text    8385 Tanglewood Court Newington, CT 06111
# Tag                                       Address
# Name: 211, dtype: object
# Text    9 Kirkland Street Lockport, NY 14094
# Tag                                  Address
# Name: 212, dtype: object
# Text    479 Joy Ridge Rd. Mansfield, MA 02048
# Tag                                   Address
# Name: 213, dtype: object
# Text    650 Country Street Saint Johns, FL 32259
# Tag                                      Address
# Name: 214, dtype: object
# Text    2 Harvey Lane Midland, MI 48640
# Tag                             Address
# Name: 215, dtype: object
# Text    972 South Marshall Ave. Elizabeth, NJ 07202
# Tag                                         Address
# Name: 216, dtype: object
# Text    353 Sussex Street Stuart, FL 34997
# Tag                                Address
# Name: 217, dtype: object
# Text    921 Old Greystone Road Medford, MA 02155
# Tag                                      Address
# Name: 218, dtype: object
# Text    8581 Sunnyslope St. Lincoln, NE 68506
# Tag                                   Address
# Name: 219, dtype: object
# Text    356 Old York Lane Woodhaven, NY 11421
# Tag                                   Address
# Name: 220, dtype: object
# Text    9973 Charles Drive Villa Park, IL 60181
# Tag                                     Address
# Name: 221, dtype: object
# Text    7459 Greenview Dr. Potomac, MD 20854
# Tag                                  Address
# Name: 222, dtype: object
# Text    5 Bellevue Ave. Des Moines, IA 50310
# Tag                                  Address
# Name: 223, dtype: object
# Text    48 Rock Maple St. Hanover Park, IL 60133
# Tag                                      Address
# Name: 224, dtype: object
# Text    9554 Shadow Brook Avenue Strongsville, OH 44136
# Tag                                             Address
# Name: 225, dtype: object
# Text    224 Miller Road Butler, PA 16001
# Tag                              Address
# Name: 226, dtype: object
# Text    95 Hawthorne Street Naples, FL 34116
# Tag                                  Address
# Name: 227, dtype: object
# Text    7859 North Princess St. Berwyn, IL 60402
# Tag                                      Address
# Name: 228, dtype: object
# Text    8471 East Drive San Lorenzo, CA 94580
# Tag                                   Address
# Name: 229, dtype: object
# Text    7464 Clay Court Newtown, PA 18940
# Tag                               Address
# Name: 230, dtype: object
# Text    723 South Dr. Morton Grove, IL 60053
# Tag                                  Address
# Name: 231, dtype: object
# Text    4 Blue Spring Street Mebane, NC 27302
# Tag                                   Address
# Name: 232, dtype: object
# Text    508 Bank St. Princeton, NJ 08540
# Tag                              Address
# Name: 233, dtype: object
# Text    538 Mountainview Street Highland Park, IL 60035
# Tag                                             Address
# Name: 234, dtype: object
# Text    8840 Addison Drive Clemmons, NC 27012
# Tag                                   Address
# Name: 235, dtype: object
# Text    512 North Brook Road Union City, NJ 07087
# Tag                                       Address
# Name: 236, dtype: object
# Text    7 Thompson Court Indianapolis, IN 46201
# Tag                                     Address
# Name: 237, dtype: object
# Text    97 Glenridge Dr. Upland, CA 91784
# Tag                               Address
# Name: 238, dtype: object
# Text    6 St Margarets Court Aiken, SC 29803
# Tag                                  Address
# Name: 239, dtype: object
# Text    55 Creekside Street Enfield, CT 06082
# Tag                                   Address
# Name: 240, dtype: object
# Text    8092 Grandrose Ave. Fairfield, CT 06824
# Tag                                     Address
# Name: 241, dtype: object
# Text    950 Tanglewood St. Cleveland, TN 37312
# Tag                                    Address
# Name: 242, dtype: object
# Text    9990 Lantern Drive East Elmhurst, NY 11369
# Tag                                        Address
# Name: 243, dtype: object
# Text    601 Jefferson Drive Hickory, NC 28601
# Tag                                   Address
# Name: 244, dtype: object
# Text    440 Bow Ridge St. Holly Springs, NC 27540
# Tag                                       Address
# Name: 245, dtype: object
# Text    7357 Winchester Drive Fairfax, VA 22030
# Tag                                     Address
# Name: 246, dtype: object
# Text    419 Greenview Ave. North Augusta, SC 29841
# Tag                                        Address
# Name: 247, dtype: object
# Text    8701 Magnolia St. Seattle, WA 98144
# Tag                                 Address
# Name: 248, dtype: object
# Text    124 Smith Store Ave. Tallahassee, FL 32303
# Tag                                        Address
# Name: 249, dtype: object
# Text    75 Greenrose Street Cartersville, GA 30120
# Tag                                        Address
# Name: 250, dtype: object
# Text    8976 Circle St. Norcross, GA 30092
# Tag                                Address
# Name: 251, dtype: object
# Text    7178 Shady St. Uniondale, NY 11553
# Tag                                Address
# Name: 252, dtype: object
# Text    73 Orange Road Davenport, IA 52804
# Tag                                Address
# Name: 253, dtype: object
# Text    392 Whitemarsh Lane Grosse Pointe, MI 48236
# Tag                                         Address
# Name: 254, dtype: object
# Text    8413 Brandywine Lane Zion, IL 60099
# Tag                                 Address
# Name: 255, dtype: object
# Text    16 Gonzales St. West Chicago, IL 60185
# Tag                                    Address
# Name: 256, dtype: object
# Text    259 Warren Dr. North Miami Beach, FL 33160
# Tag                                        Address
# Name: 257, dtype: object
# Text    19 Brickyard Rd. Deerfield Beach, FL 33442
# Tag                                        Address
# Name: 258, dtype: object
# Text    434 Greenrose Avenue Harvey, IL 60426
# Tag                                   Address
# Name: 259, dtype: object
# Text    447 Fairfield Lane Clarksville, TN 37040
# Tag                                      Address
# Name: 260, dtype: object
# Text    8460 S. Hillside Avenue Brandon, FL 33510
# Tag                                       Address
# Name: 261, dtype: object
# Text    7485 High Noon Drive Galloway, OH 43119
# Tag                                     Address
# Name: 262, dtype: object
# Text    44 Riverview Road Irwin, PA 15642
# Tag                               Address
# Name: 263, dtype: object
# Text    9468 Brickell Court Chicopee, MA 01020
# Tag                                    Address
# Name: 264, dtype: object
# Text    7679 Oakland St. Laurel, MD 20707
# Tag                               Address
# Name: 265, dtype: object
# Text    67 Marlborough Dr. Menomonee Falls, WI 53051
# Tag                                          Address
# Name: 266, dtype: object
# Text    9561 Mountainview Road Latrobe, PA 15650
# Tag                                      Address
# Name: 267, dtype: object
# Text    8305 Thorne Lane Reno, NV 89523
# Tag                             Address
# Name: 268, dtype: object
# Text    9597 NW. Harrison Rd. Findlay, OH 45840
# Tag                                     Address
# Name: 269, dtype: object
# Text    319 Greystone Ave. Cranberry Twp, PA 16066
# Tag                                        Address
# Name: 270, dtype: object
# Text    324 Park Street Glendora, CA 91740
# Tag                                Address
# Name: 271, dtype: object
# Text    9386 Illinois Road Westford, MA 01886
# Tag                                   Address
# Name: 272, dtype: object
# Text    9025 South Walt Whitman Avenue Shrewsbury, MA ...
# Tag                                               Address
# Name: 273, dtype: object
# Text    542 N. Clinton St. Sacramento, CA 95820
# Tag                                     Address
# Name: 274, dtype: object
# Text    8736 Grand St. Eden Prairie, MN 55347
# Tag                                   Address
# Name: 275, dtype: object
# Text    199 Foxrun Drive Bear, DE 19701
# Tag                             Address
# Name: 276, dtype: object
# Text    872 Bishop St. Campbell, CA 95008
# Tag                               Address
# Name: 277, dtype: object
# Text    271 Plumb Branch Road Miami, FL 33125
# Tag                                   Address
# Name: 278, dtype: object
# Text    7809 S. Pheasant Court Fairmont, WV 26554
# Tag                                       Address
# Name: 279, dtype: object
# Text    52 Clinton Rd. Addison, IL 60101
# Tag                              Address
# Name: 280, dtype: object
# Text    187 Thatcher St. Royersford, PA 19468
# Tag                                   Address
# Name: 281, dtype: object
# Text    9 Miles St. East Meadow, NY 11554
# Tag                               Address
# Name: 282, dtype: object
# Text    17 West Griffin Ave. Everett, MA 02149
# Tag                                    Address
# Name: 283, dtype: object
# Text    7605 Border Rd. Ottawa, IL 61350
# Tag                              Address
# Name: 284, dtype: object
# Text    91 Highland St. Pueblo, CO 81001
# Tag                              Address
# Name: 285, dtype: object
# Text    9380 Rockledge Street Lincolnton, NC 28092
# Tag                                        Address
# Name: 286, dtype: object
# Text    91 West Grandrose Avenue North Kingstown, RI 0...
# Tag                                               Address
# Name: 287, dtype: object
# Text    387 Howard St. Sewell, NJ 08080
# Tag                             Address
# Name: 288, dtype: object
# Text    934 Cleveland St. Capitol Heights, MD 20743
# Tag                                         Address
# Name: 289, dtype: object
# Text    9041 NE. Acacia Drive Waukegan, IL 60085
# Tag                                      Address
# Name: 290, dtype: object
# Text    80 Wagon St. Canonsburg, PA 15317
# Tag                               Address
# Name: 291, dtype: object
# Text    987 South Front Rd. Lanham, MD 20706
# Tag                                  Address
# Name: 292, dtype: object
# Text    7706 Pearl Circle Fitchburg, MA 01420
# Tag                                   Address
# Name: 293, dtype: object
# Text    15 E. Prospect Ave. Butte, MT 59701
# Tag                                 Address
# Name: 294, dtype: object
# Text    86 Greenrose Drive Cherry Hill, NJ 08003
# Tag                                      Address
# Name: 295, dtype: object
# Text    9324 Fairground Ave. Jeffersonville, IN 47130
# Tag                                           Address
# Name: 296, dtype: object
# Text    140 Honey Creek Dr. Morganton, NC 28655
# Tag                                     Address
# Name: 297, dtype: object
# Text    8044 Southampton Street Eastlake, OH 44095
# Tag                                        Address
# Name: 298, dtype: object
# Text    9676 Edgewater Ave. Mooresville, NC 28115
# Tag                                       Address
# Name: 299, dtype: object
# Text    8 Canal Ave. Virginia Beach, VA 23451
# Tag                                   Address
# Name: 300, dtype: object
# Text    9964 Summit Street Schererville, IN 46375
# Tag                                       Address
# Name: 301, dtype: object
# Text    90 Devonshire Avenue Ithaca, NY 14850
# Tag                                   Address
# Name: 302, dtype: object
# Text    9603 Tower Road Willingboro, NJ 08046
# Tag                                   Address
# Name: 303, dtype: object
# Text    272 Foster St. Nashville, TN 37205
# Tag                                Address
# Name: 304, dtype: object
# Text    40 Garden Ave. Waukesha, WI 53186
# Tag                               Address
# Name: 305, dtype: object
# Text    219 Amherst Ave. Windermere, FL 34786
# Tag                                   Address
# Name: 306, dtype: object
# Text    7071 E. 8th St. Bethesda, MD 20814
# Tag                                Address
# Name: 307, dtype: object
# Text    554 Sutor Ave. Graham, NC 27253
# Tag                             Address
# Name: 308, dtype: object
# Text    101 Augusta Court Cedar Rapids, IA 52402
# Tag                                      Address
# Name: 309, dtype: object
# Text    970 George Ave. Piqua, OH 45356
# Tag                             Address
# Name: 310, dtype: object
# Text    8125 Wild Rose Ave. Palm City, FL 34990
# Tag                                     Address
# Name: 311, dtype: object
# Text    222 Bradford Dr. Shepherdsville, KY 40165
# Tag                                       Address
# Name: 312, dtype: object
# Text    7562 Carriage Lane Flowery Branch, GA 30542
# Tag                                         Address
# Name: 313, dtype: object
# Text    53 Brickell Lane Jackson, NJ 08527
# Tag                                Address
# Name: 314, dtype: object
# Text    238 South Queen Street Apopka, FL 32703
# Tag                                     Address
# Name: 315, dtype: object
# Text    537 Bayberry Ave. Hopewell, VA 23860
# Tag                                  Address
# Name: 316, dtype: object
# Text    9256 Winchester Street North Royalton, OH 44133
# Tag                                             Address
# Name: 317, dtype: object
# Text    95 Fairfield St. Frankfort, KY 40601
# Tag                                  Address
# Name: 318, dtype: object
# Text    61 Piper Lane Culpeper, VA 22701
# Tag                              Address
# Name: 319, dtype: object
# Text    7782 Wrangler Dr. Sicklerville, NJ 08081
# Tag                                      Address
# Name: 320, dtype: object
# Text    77 South Beacon Street Omaha, NE 68107
# Tag                                    Address
# Name: 321, dtype: object
# Text    371 Gartner Dr. Amityville, NY 11701
# Tag                                  Address
# Name: 322, dtype: object
# Text    7 Pacific Drive Orland Park, IL 60462
# Tag                                   Address
# Name: 323, dtype: object
# Text    9557 Arch Ave. Stillwater, MN 55082
# Tag                                 Address
# Name: 324, dtype: object
# Text    70 Edgewood St. Rowlett, TX 75088
# Tag                               Address
# Name: 325, dtype: object
# Text    7379 South Cardinal Court Londonderry, NH 03053
# Tag                                             Address
# Name: 326, dtype: object
# Text    46 Washington Street Rocky Mount, NC 27804
# Tag                                        Address
# Name: 327, dtype: object
# Text    9368 Hawthorne Drive Fort Lauderdale, FL 33308
# Tag                                            Address
# Name: 328, dtype: object
# Text    615 Philmont St. Elgin, IL 60120
# Tag                              Address
# Name: 329, dtype: object
# Text    8977 Foxrun Rd. Sun City, AZ 85351
# Tag                                Address
# Name: 330, dtype: object
# Text    9109 North Brown Drive Skokie, IL 60076
# Tag                                     Address
# Name: 331, dtype: object
# Text    781 South Yukon Lane Oxford, MS 38655
# Tag                                   Address
# Name: 332, dtype: object
# Text    485 West Walnutwood St. Wethersfield, CT 06109
# Tag                                            Address
# Name: 333, dtype: object
# Text    560 Cedar Swamp Street Emporia, KS 66801
# Tag                                      Address
# Name: 334, dtype: object
# Text    8826 Pulaski Ave. Mokena, IL 60448
# Tag                                Address
# Name: 335, dtype: object
# Text    7166 Constitution Dr. Kissimmee, FL 34741
# Tag                                       Address
# Name: 336, dtype: object
# Text    7493 Marvon St. Griffin, GA 30223
# Tag                               Address
# Name: 337, dtype: object
# Text    7269 Newcastle Circle Ypsilanti, MI 48197
# Tag                                       Address
# Name: 338, dtype: object
# Text    95 Princess Rd. Auburndale, FL 33823
# Tag                                  Address
# Name: 339, dtype: object
# Text    200 San Pablo Court Cordova, TN 38016
# Tag                                   Address
# Name: 340, dtype: object
# Text    425 Magnolia Rd. Dearborn, MI 48124
# Tag                                 Address
# Name: 341, dtype: object
# Text    7583 Monroe Street Lynn, MA 01902
# Tag                               Address
# Name: 342, dtype: object
# Text    12 Military Rd. East Lansing, MI 48823
# Tag                                    Address
# Name: 343, dtype: object
# Text    61 Rock Maple Street Spring Hill, FL 34608
# Tag                                        Address
# Name: 344, dtype: object
# Text    882 W. Railroad Street Hinesville, GA 31313
# Tag                                         Address
# Name: 345, dtype: object
# Text    7 Buckingham Court Elizabethtown, PA 17022
# Tag                                        Address
# Name: 346, dtype: object
# Text    9 Coffee Drive Bloomington, IN 47401
# Tag                                  Address
# Name: 347, dtype: object
# Text    10 E. Prince St. Palm Beach Gardens, FL 33410
# Tag                                           Address
# Name: 348, dtype: object
# Text    270 N. Green Hill Ave. Hummelstown, PA 17036
# Tag                                          Address
# Name: 349, dtype: object
# Text    217 Iroquois Avenue Defiance, OH 43512
# Tag                                    Address
# Name: 350, dtype: object
# Text    95 Mayfair Avenue State College, PA 16801
# Tag                                       Address
# Name: 351, dtype: object
# Text    847 SE. Golden Star Lane Riverview, FL 33569
# Tag                                          Address
# Name: 352, dtype: object
# Text    8317 Silver Spear St. Camas, WA 98607
# Tag                                   Address
# Name: 353, dtype: object
# Text    386 Bald Hill St. Romulus, MI 48174
# Tag                                 Address
# Name: 354, dtype: object
# Text    41 Vine Street Richmond, VA 23223
# Tag                               Address
# Name: 355, dtype: object
# Text    7964 Adams Lane Lawndale, CA 90260
# Tag                                Address
# Name: 356, dtype: object
# Text    68 Wentworth St. Sterling, VA 20164
# Tag                                 Address
# Name: 357, dtype: object
# Text    46 Race St. Natick, MA 01760
# Tag                          Address
# Name: 358, dtype: object
# Text    31 Holly Street Summerfield, FL 34491
# Tag                                   Address
# Name: 359, dtype: object
# Text    725 North Logan Drive Niagara Falls, NY 14304
# Tag                                           Address
# Name: 360, dtype: object
# Text    737 West Livingston Drive Libertyville, IL 60048
# Tag                                              Address
# Name: 361, dtype: object
# Text    4 George Ave. Rosemount, MN 55068
# Tag                               Address
# Name: 362, dtype: object
# Text    7794 Hudson St. Shirley, NY 11967
# Tag                               Address
# Name: 363, dtype: object
# Text    9251 Roberts Ave. Holland, MI 49423
# Tag                                 Address
# Name: 364, dtype: object
# Text    61 Old York Ave. Mesa, AZ 85203
# Tag                             Address
# Name: 365, dtype: object
# Text    9356 North Division Lane Pickerington, OH 43147
# Tag                                             Address
# Name: 366, dtype: object
# Text    494 Carpenter Lane East Haven, CT 06512
# Tag                                     Address
# Name: 367, dtype: object
# Text    8369 Bohemia Avenue Yorktown, VA 23693
# Tag                                    Address
# Name: 368, dtype: object
# Text    625 Littleton Street Mount Vernon, NY 10550
# Tag                                         Address
# Name: 369, dtype: object
# Text    495 Tunnel Street Cranston, RI 02920
# Tag                                  Address
# Name: 370, dtype: object
# Text    112 South Warren Street Glen Burnie, MD 21060
# Tag                                           Address
# Name: 371, dtype: object
# Text    77 Winchester Drive Middletown, CT 06457
# Tag                                      Address
# Name: 372, dtype: object
# Text    14 Glenwood St. Suite 199
# Tag                        Address
# Name: 373, dtype: object
# Text    Buffalo Grove, IL 60089575 Prospect Avenue
# Tag                                         Address
# Name: 374, dtype: object
# Text    Danville, VA 245407223 Pilgrim Rd.
# Tag                                 Address
# Name: 375, dtype: object
# Text    Durham, NC 277038278 West Ryan Drive
# Tag                                   Address
# Name: 376, dtype: object
# Text    Thibodaux, LA 70301303 Hamilton Avenue
# Tag                                     Address
# Name: 377, dtype: object
# Text    Paducah, KY 4200188 Spring Road
# Tag                              Address
# Name: 378, dtype: object
# Text    Syosset, NY 1179130 Williams Lane
# Tag                                Address
# Name: 379, dtype: object
# Text    Ellenwood, GA 30294666 Linda Ave.
# Tag                                Address
# Name: 380, dtype: object
# Text    Dubuque, IA 520019415 Grandrose Ave.
# Tag                                   Address
# Name: 381, dtype: object
# Text    Montgomery Village, MD 20886512 Manor St.
# Tag                                        Address
# Name: 382, dtype: object
# Text    North Canton, OH 44720332 Sulphur Springs Lane
# Tag                                             Address
# Name: 383, dtype: object
# Text    Lake Villa, IL 6004693 Old Rocky River Dr.
# Tag                                         Address
# Name: 384, dtype: object
# Text    Alexandria, VA 22304988 James Street
# Tag                                   Address
# Name: 385, dtype: object
# Text    Delaware, OH 430158186 Ohio St.
# Tag                              Address
# Name: 386, dtype: object
# Text    Onalaska, WI 54650695 Wrangler Rd.
# Tag                                 Address
# Name: 387, dtype: object
# Text    Suite 4 Maumee, OH 43537
# Tag                      Address
# Name: 388, dtype: object
# Text    949 Country Street Sandusky, OH 44870
# Tag                                   Address
# Name: 389, dtype: object
# Text    9664 Roehampton Ave. Elmont, NY 11003
# Tag                                   Address
# Name: 390, dtype: object
# Text    497 Summit St. Massillon, OH 44646
# Tag                                Address
# Name: 391, dtype: object
# Text    699 West Peg Shop St. Kent, OH 44240
# Tag                                  Address
# Name: 392, dtype: object
# Text    540 Hudson St. New Britain, CT 06051
# Tag                                  Address
# Name: 393, dtype: object
# Text    218 High Point Ave. Paterson, NJ 07501
# Tag                                    Address
# Name: 394, dtype: object
# Text    27 Nichols St. Vernon Rockville, CT 06066
# Tag                                       Address
# Name: 395, dtype: object
# Text    35 SE. Canterbury Drive Cornelius, NC 28031
# Tag                                         Address
# Name: 396, dtype: object
# Text    356 Cobblestone Lane Suitland, MD 20746
# Tag                                     Address
# Name: 397, dtype: object
# Text    8371 Thatcher Rd. Mobile, AL 36605
# Tag                                Address
# Name: 398, dtype: object
# Text    8206 School Dr. King Of Prussia, PA 19406
# Tag                                       Address
# Name: 399, dtype: object
# Text    518 Bear Hill Ave. Clifton Park, NY 12065
# Tag                                       Address
# Name: 400, dtype: object
# Text    8343 Bow Ridge Rd. Chapel Hill, NC 27516
# Tag                                      Address
# Name: 401, dtype: object
# Text    38 Border Court La Porte, IN 46350
# Tag                                Address
# Name: 402, dtype: object
# Text    51 Roehampton Avenue South Richmond Hill, NY 1...
# Tag                                               Address
# Name: 403, dtype: object
# Text    7734 Eagle St. Kaukauna, WI 54130
# ...
# Tag                                                   NaN
# Name: 11128, dtype: object
# Text    <sentence id="s433">
# Tag                      NaN
# Name: 11129, dtype: object
# Text     (k) The amount of the Scheme Company's share ...
# Tag                                                   NaN
# Name: 11130, dtype: object
# Text    <sentence id="s434">(l) The amount of the rele...
# Tag                                                   NaN
# Name: 11131, dtype: object
# Text    <sentence id="s435">4.7 Determination of Final...
# Tag                                                   NaN
# Name: 11132, dtype: object
# Text    <sentence id="s436">For the avoidance of doubt...
# Tag                                                   NaN
# Name: 11133, dtype: object
# Text    <sentence id="s437">
# Tag                      NaN
# Name: 11134, dtype: object
# Text     (b) The Scheme Company shall notify the Schem...
# Tag                                                   NaN
# Name: 11135, dtype: object
# Text    <sentence id="s438">Except in the case of mani...
# Tag                                                   NaN
# Name: 11136, dtype: object
# Text    <sentence id="s439">
# Tag                      NaN
# Name: 11137, dtype: object
# Text     Where no such challenge is made within this 3...
# Tag                                                   NaN
# Name: 11138, dtype: object
# Text    <sentence id="s440">
# Tag                      NaN
# Name: 11139, dtype: object
# Text     (c) If a Scheme Creditor wishes to challenge ...
# Tag                                                   NaN
# Name: 11140, dtype: object
# Text    <sentence id="s441">The Scheme Company and the...
# Tag                                                   NaN
# Name: 11141, dtype: object
# Text    <sentence id="s442">In the event that a set-of...
# Tag                                                   NaN
# Name: 11142, dtype: object
# Text    <sentence id="s443">(d) If the disputed matter...
# Tag                                                   NaN
# Name: 11143, dtype: object
# Text    <sentence id="s444">If such notification is re...
# Tag                                                   NaN
# Name: 11144, dtype: object
# Text    <sentence id="s445">If the Scheme Creditor doe...
# Tag                                                   NaN
# Name: 11145, dtype: object
# Text    <sentence id="s446">(e) The Scheme Adjudicator...
# Tag                                                   NaN
# Name: 11146, dtype: object
# Text    <sentence id="s447">(f) In determining the val...
# Tag                                                   NaN
# Name: 11147, dtype: object
# Text    <sentence id="s448">(g) The value of a Scheme ...
# Tag                                                   NaN
# Name: 11148, dtype: object
# Text    <sentence id="s449">4.8 Extension of time limi...
# Tag                                                   NaN
# Name: 11149, dtype: object
# Text    <sentence id="s450">
# Tag                      NaN
# Name: 11150, dtype: object
# Text     4.9 Scheme Creditors to provide assistance (a...
# Tag                                                   NaN
# Name: 11151, dtype: object
# Text    <sentence id="s451">(b) The Scheme Company sha...
# Tag                                                   NaN
# Name: 11152, dtype: object
# Text    <sentence id="s452">4.10 Set-off (a) Where a S...
# Tag                                                   NaN
# Name: 11153, dtype: object
# Text    <sentence id="s453">Sums (including contingent...
# Tag                                                   NaN
# Name: 11154, dtype: object
# Text    <sentence id="s454">For the avoidance of doubt...
# Tag                                                   NaN
# Name: 11155, dtype: object
# Text    <sentence id="s455">(b) For the avoidance of d...
# Tag                                                   NaN
# Name: 11156, dtype: object
# Text    <sentence id="s456">(c) Only the balance of an...
# Tag                                                   NaN
# Name: 11157, dtype: object
# Text    <sentence id="s457">(d) The discount applying ...
# Tag                                                   NaN
# Name: 11158, dtype: object
# Text    <sentence id="s458">4.11 Treatment of agents T...
# Tag                                                   NaN
# Name: 11159, dtype: object
# Text    <sentence id="s459">
# Tag                      NaN
# Name: 11160, dtype: object
# Text     4.12 Funding (a) Brokers who have funded Clai...
# Tag                                                   NaN
# Name: 11161, dtype: object
# Text    <sentence id="s460">(b) For the avoidance of d...
# Tag                                                   NaN
# Name: 11162, dtype: object
# Text    <sentence id="s461">The supporting information...
# Tag                                                   NaN
# Name: 11163, dtype: object
# Text    <sentence id="s462">4.13 Currency Except where...
# Tag                                                   NaN
# Name: 11164, dtype: object
# Text    <sentence id="s463">(b) For the purpose of cla...
# Tag                                                   NaN
# Name: 11165, dtype: object
# Text    <sentence id="s464">(c) For the purpose of con...
# Tag                                                   NaN
# Name: 11166, dtype: object
# Text    <sentence id="s465">(d) Final Determined Claim...
# Tag                                                   NaN
# Name: 11167, dtype: object
# Text    <sentence id="s466">(e) Where a Scheme Credito...
# Tag                                                   NaN
# Name: 11168, dtype: object
# Text    <sentence id="s467">4.14 Payment of Final Dete...
# Tag                                                   NaN
# Name: 11169, dtype: object
# Text    <sentence id="s468">(b) The Scheme Company sha...
# Tag                                                   NaN
# Name: 11170, dtype: object
# Text    <sentence id="s469">Where the Scheme Company f...
# Tag                                                   NaN
# Name: 11171, dtype: object
# Text    <sentence id="s470">For the avoidance of doubt...
# Tag                                                   NaN
# Name: 11172, dtype: object
# Text    <sentence id="s471">(c) All payments pursuant ...
# Tag                                                   NaN
# Name: 11173, dtype: object
# Text    <sentence id="s472">
# Tag                      NaN
# Name: 11174, dtype: object
# Text     (d) Subject to clause 4.14 (e) below, any pay...
# Tag                                                   NaN
# Name: 11175, dtype: object
# Text    <sentence id="s473">The Final Determined Claim...
# Tag                                                   NaN
# Name: 11176, dtype: object
# Text    <sentence id="s474">(e) The Scheme Company res...
# Tag                                                   NaN
# Name: 11177, dtype: object
# Text    <sentence id="s475">(f) Payments made pursuant...
# Tag                                                   NaN
# Name: 11178, dtype: object
# Text    <sentence id="s476">For the purpose of this cl...
# Tag                                                   NaN
# Name: 11179, dtype: object
# Text    <sentence id="s477">4.15 No release Subject to...
# Tag                                                   NaN
# Name: 11180, dtype: object
# Text    <sentence id="s478">
# Tag                      NaN
# Name: 11181, dtype: object
# Text     4.16 Corporations Act appeal rights Despite a...
# Tag                                                   NaN
# Name: 11182, dtype: object
# Text    <sentence id="s479">
# Tag                      NaN
# Name: 11183, dtype: object
# Text     5.</sentence>
# Tag                NaN
# Name: 11184, dtype: object
# Text    <sentence id="s480">The Scheme Actuary 5.1 The...
# Tag                                                   NaN
# Name: 11185, dtype: object
# Text    <sentence id="s481">(b) The Scheme Actuary sha...
# Tag                                                   NaN
# Name: 11186, dtype: object
# Text    <sentence id="s482">(c) The Scheme Actuary sha...
# Tag                                                   NaN
# Name: 11187, dtype: object
# Text    <sentence id="s483">(d) The Scheme Actuary sha...
# Tag                                                   NaN
# Name: 11188, dtype: object
# Text    <sentence id="s484">(e) The office of Scheme A...
# Tag                                                   NaN
# Name: 11189, dtype: object
# Text    <sentence id="s485">(f) In the event of a vaca...
# Tag                                                   NaN
# Name: 11190, dtype: object
# Text    <sentence id="s486">The Scheme Company will no...
# Tag                                                   NaN
# Name: 11191, dtype: object
# Text    <sentence id="s487">(g) The Scheme Actuary sha...
# Tag                                                   NaN
# Name: 11192, dtype: object
# Text    <sentence id="s488">5.2 Responsibility and ind...
# Tag                                                   NaN
# Name: 11193, dtype: object
# Text    <sentence id="s489">(b) Subject to the Act, th...
# Tag                                                   NaN
# Name: 11194, dtype: object
# Text    <sentence id="s490">(c) The Scheme Company may...
# Tag                                                   NaN
# Name: 11195, dtype: object
# Text    <sentence id="s491">6.</sentence>
# Tag                                   NaN
# Name: 11196, dtype: object
# Text    <sentence id="s492">The Scheme Adjudicator 6.1...
# Tag                                                   NaN
# Name: 11197, dtype: object
# Text    <sentence id="s493">The first Scheme Adjudicat...
# Tag                                                   NaN
# Name: 11198, dtype: object
# Text    <sentence id="s494">If the relevant Scheme Cre...
# Tag                                                   NaN
# Name: 11199, dtype: object
# Text    <sentence id="s495">If the Scheme Creditor obj...
# Tag                                                   NaN
# Name: 11200, dtype: object
# Text    <sentence id="s496">The Scheme Adjudicator's a...
# Tag                                                   NaN
# Name: 11201, dtype: object
# Text    <sentence id="s497">
# Tag                      NaN
# Name: 11202, dtype: object
# Text     (c) For the avoidance of doubt, the provision...
# Tag                                                   NaN
# Name: 11203, dtype: object
# Text    <sentence id="s498">(d) The Scheme Adjudicator...
# Tag                                                   NaN
# Name: 11204, dtype: object
# Text    <sentence id="s499">Any such waiver of a confl...
# Tag                                                   NaN
# Name: 11205, dtype: object
# Text    <sentence id="s500">(e) The office of Scheme A...
# Tag                                                   NaN
# Name: 11206, dtype: object
# Text    <sentence id="s501">
# Tag                      NaN
# Name: 11207, dtype: object
# Text     (f) Any alternate or replacement Scheme Adjud...
# Tag                                                   NaN
# Name: 11208, dtype: object
# Text    <sentence id="s502">6.2 Powers, rights, duties...
# Tag                                                   NaN
# Name: 11209, dtype: object
# Text    <sentence id="s503">(b) The Scheme Adjudicator...
# Tag                                                   NaN
# Name: 11210, dtype: object
# Text    <sentence id="s504">Subject to clauses 4.6(j) ...
# Tag                                                   NaN
# Name: 11211, dtype: object
# Text    <sentence id="s505">6.3 Responsibility and ind...
# Tag                                                   NaN
# Name: 11212, dtype: object
# Text    <sentence id="s506">(b) No Scheme Creditor sha...
# Tag                                                   NaN
# Name: 11213, dtype: object
# Text    <sentence id="s507">(c) Subject to the Act, th...
# Tag                                                   NaN
# Name: 11214, dtype: object
# Text    <sentence id="s508">(d) The Scheme Company may...
# Tag                                                   NaN
# Name: 11215, dtype: object
# Text    <sentence id="s509">7.</sentence>
# Tag                                   NaN
# Name: 11216, dtype: object
# Text    <sentence id="s510">The Board The powers of th...
# Tag                                                   NaN
# Name: 11217, dtype: object
# Text    <sentence id="s511">
# Tag                      NaN
# Name: 11218, dtype: object
# Text     8.</sentence>
# Tag                NaN
# Name: 11219, dtype: object
# Text    <sentence id="s512">Termination of the Scheme ...
# Tag                                                   NaN
# Name: 11220, dtype: object
# Text    <sentence id="s513">The date of such confirmat...
# Tag                                                   NaN
# Name: 11221, dtype: object
# Text    <sentence id="s514">This confirmation shall be...
# Tag                                                   NaN
# Name: 11222, dtype: object
# Text    <sentence id="s515">The Scheme Adjudicator and...
# Tag                                                   NaN
# Name: 11223, dtype: object
# Text    <sentence id="s516">
# Tag                      NaN
# Name: 11224, dtype: object
# Text     8.2 Reversion to run-off (a) If at any time o...
# Tag                                                   NaN
# Name: 11225, dtype: object
# Text    <sentence id="s517">(b) If the business of the...
# Tag                                                   NaN
# Name: 11226, dtype: object
# Text    <sentence id="s518">For this purpose a Final D...
# Tag                                                   NaN
# Name: 11227, dtype: object
# Text    <sentence id="s519">8.3 Provisions surviving t...
# Tag                                                   NaN
# Name: 11228, dtype: object
# Text    <sentence id="s520">
# Tag                      NaN
# Name: 11229, dtype: object
# Text     9.</sentence>
# Tag                NaN
# Name: 11230, dtype: object
# Text    <sentence id="s521">General Scheme provisions ...
# Tag                                                   NaN
# Name: 11231, dtype: object
# Text    <sentence id="s522">
# Tag                      NaN
# Name: 11232, dtype: object
# Text     9.2 Pre-Scheme Expenses and Scheme Costs (a) ...
# Tag                                                   NaN
# Name: 11233, dtype: object
# Text    <sentence id="s523">(b) There shall be paid in...
# Tag                                                   NaN
# Name: 11234, dtype: object
# Text    <sentence id="s524">9.3 Modification of the Sc...
# Tag                                                   NaN
# Name: 11235, dtype: object
# Text    <sentence id="s525">
# Tag                      NaN
# Name: 11236, dtype: object
# Text     9.4 Notices (a) Without prejudice to clause 4...
# Tag                                                   NaN
# Name: 11237, dtype: object
# Text    <sentence id="s526">(b) Except as otherwise pr...
# Tag                                                   NaN
# Name: 11238, dtype: object
# Text    <sentence id="s527">(c) In proving service, it...
# Tag                                                   NaN
# Name: 11239, dtype: object
# Text    <sentence id="s528">(d) For the purposes of cl...
# Tag                                                   NaN
# Name: 11240, dtype: object
# Text    <sentence id="s529">9.5 Calculation of time pe...
# Tag                                                   NaN
# Name: 11241, dtype: object
# Text    <sentence id="s530">In the event that a time p...
# Tag                                                   NaN
# Name: 11242, dtype: object
# Text    <sentence id="s531">
# Tag                      NaN
# Name: 11243, dtype: object
# Text     9.6 Governing law and jurisdiction (a) The Sc...
# Tag                                                   NaN
# Name: 11244, dtype: object
# Text    <sentence id="s532">(b) The Scheme Creditors h...
# Tag                                                   NaN
# Name: 11245, dtype: object
# Text    <sentence id="s533">(c) The Scheme Creditors i...
# Tag                                                   NaN
# Name: 11246, dtype: object
# Text    <sentence id="s534">(d) Nothing in this clause...
# Tag                                                   NaN
# Name: 11247, dtype: object
# Text    <sentence id="s535">(e) Notwithstanding the pr...
# Tag                                                   NaN
# Name: 11248, dtype: object

# %%
model = Doc2Vec(sentences, min_count=1, window=100, size=50, workers=7, iter = 20)
print(sentences[1:4])
print('vocab done*********************')
model.train(sentences, epochs=model.iter, total_examples=model.corpus_count)
model.save('./new_imdb_withoutID_medium.d2v')

	# MODEL PARAMETERS
