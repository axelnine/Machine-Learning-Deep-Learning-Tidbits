# %%
# gensim modules
from gensim import utils
from gensim.models.doc2vec import LabeledSentence, TaggedDocument
from gensim.models import Doc2Vec
import pandas as pd
# numpy
import numpy

# shuffle
from random import shuffle

# logging
import logging
import os.path
import sys
import cloudpickle as pickle

# %%
program = os.path.basename(sys.argv[0])
logger = logging.getLogger(program)
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s')
logging.root.setLevel(level=logging.INFO)
logger.info("running %s" % ' '.join(sys.argv))
# Out:
# 2019-04-07 11:32:53,512 : INFO : running C:\Anaconda3\lib\site-packages\ipykernel_launcher.py -f C:\Users\Prem Shah\AppData\Roaming\jupyter\runtime\kernel-fdfb5fa2-21bf-4641-a044-c4dde0c3c863.json

# %%
data = pd.read_csv('Data.csv')
print("******************")
print(len(data))
data.head()
# Out:
# ******************
# 11249
#                                            Text      Tag
# 0            7710 Tower Street Hamden, CT 06514  Address
# 1            932 Bishop St. Billerica, MA 01821  Address
# 2      7906 Silver Spear Road Davison, MI 48423  Address
# 3       9739 Acacia Lane Beaver Falls, PA 15010  Address
# 4  712 Oak Valley Street Temple Hills, MD 20748  Address

# %%
sentences= []
for elem in data.iterrows():
    tup = elem[1]
    ids = [tup['Tag']]
    a = str(tup['Text']).split(' ')
    t = [x.replace('}', '').replace('(', '').replace('.', ' ').replace(')', '').replace('{', '').replace(';', '').replace('-', '').replace('_', ' ') for x in a if(x != '')]
    sentences.append(LabeledSentence(t, ids))
    if(len(sentences)%500 == 0):
        print(len(sentences))
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: Call to deprecated `LabeledSentence` (Class will be removed in 4.0.0, use TaggedDocument instead).
#   import sys
# 500
# 1000
# 1500
# 2000
# 2500
# 3000
# 3500
# 4000
# 4500
# 5000
# 5500
# 6000
# 6500
# 7000
# 7500
# 8000
# 8500
# 9000
# 9500
# 10000
# 10500
# 11000

# %%
sentences
# Out:
# [LabeledSentence(words=['7710', 'Tower', 'Street\xa0Hamden,', 'CT', '06514'], tags=['Address']),
#  LabeledSentence(words=['932', 'Bishop', 'St \xa0Billerica,', 'MA', '01821'], tags=['Address']),
#  LabeledSentence(words=['7906', 'Silver', 'Spear', 'Road\xa0Davison,', 'MI', '48423'], tags=['Address']),
#  LabeledSentence(words=['9739', 'Acacia', 'Lane\xa0Beaver', 'Falls,', 'PA', '15010'], tags=['Address']),
#  LabeledSentence(words=['712', 'Oak', 'Valley', 'Street\xa0Temple', 'Hills,', 'MD', '20748'], tags=['Address']),
#  LabeledSentence(words=['8940', 'Queen', 'Ave \xa0Scarsdale,', 'NY', '10583'], tags=['Address']),
#  LabeledSentence(words=['8262', 'Hartford', 'St \xa0Valley', 'Stream,', 'NY', '11580'], tags=['Address']),
#  LabeledSentence(words=['51', 'Cross', 'Dr \xa0Ridgefield,', 'CT', '06877'], tags=['Address']),
#  LabeledSentence(words=['43', 'Mill', 'Pond', 'St \xa0Parsippany,', 'NJ', '07054'], tags=['Address']),
#  LabeledSentence(words=['40', 'Canterbury', 'Road\xa0Belmont,', 'MA', '02478'], tags=['Address']),
#  LabeledSentence(words=['9263', 'Oxford', 'Ave \xa0Kansas', 'City,', 'MO', '64151'], tags=['Address']),
#  LabeledSentence(words=['8564', 'Jackson', 'Street\xa0Pearl,', 'MS', '39208'], tags=['Address']),
#  LabeledSentence(words=['845', 'W ', 'Third', 'St \xa0Ridgecrest,', 'CA', '93555'], tags=['Address']),
#  LabeledSentence(words=['265', 'Lafayette', 'St \xa0Sterling', 'Heights,', 'MI', '48310'], tags=['Address']),
#  LabeledSentence(words=['5', 'Cooper', 'Street\xa0Rockledge,', 'FL', '32955'], tags=['Address']),
#  LabeledSentence(words=['7187', 'Del', 'Monte', 'Avenue\xa0Cumming,', 'GA', '30040'], tags=['Address']),
#  LabeledSentence(words=['283B', 'Second', 'Court\xa0Beckley,', 'WV', '25801'], tags=['Address']),
#  LabeledSentence(words=['78', 'W ', 'Hilltop', 'Drive\xa0Longwood,', 'FL', '32779'], tags=['Address']),
#  LabeledSentence(words=['416', 'W ', 'Mulberry', 'Ave \xa0Pottstown,', 'PA', '19464'], tags=['Address']),
#  LabeledSentence(words=['984', 'Westminster', 'Street\xa0Ladson,', 'SC', '29456'], tags=['Address']),
#  LabeledSentence(words=['546', 'James', 'Ave \xa0Andover,', 'MA', '01810'], tags=['Address']),
#  LabeledSentence(words=['13', 'Cobblestone', 'Road\xa0Yuma,', 'AZ', '85365'], tags=['Address']),
#  LabeledSentence(words=['8814', 'Wakehurst', 'Road\xa0Land', 'O', 'Lakes,', 'FL', '34639'], tags=['Address']),
#  LabeledSentence(words=['2', 'Indian', 'Spring', 'Street\xa0Blackwood,', 'NJ', '08012'], tags=['Address']),
#  LabeledSentence(words=['9303', 'Clark', 'Drive\xa0Dawsonville,', 'GA', '30534'], tags=['Address']),
#  LabeledSentence(words=['8246', 'West', 'Cottage', 'Street\xa0Alpharetta,', 'GA', '30004'], tags=['Address']),
#  LabeledSentence(words=['69', 'Meadow', 'Ave \xa0Logansport,', 'IN', '46947'], tags=['Address']),
#  LabeledSentence(words=['615', 'Windsor', 'St \xa0Reading,', 'MA', '01867'], tags=['Address']),
#  LabeledSentence(words=['9487', 'W ', 'Kirkland', 'Ave \xa0New', 'Lenox,', 'IL', '60451'], tags=['Address']),
#  LabeledSentence(words=['70', 'Plymouth', 'St \xa0Chaska,', 'MN', '55318'], tags=['Address']),
#  LabeledSentence(words=['9892', 'Arrowhead', 'Street\xa0Mcminnville,', 'TN', '37110'], tags=['Address']),
#  LabeledSentence(words=['9915', 'Nut', 'Swamp', 'Road\xa0Encino,', 'CA', '91316'], tags=['Address']),
#  LabeledSentence(words=['656', 'Holly', 'Drive\xa0Taylors,', 'SC', '29687'], tags=['Address']),
#  LabeledSentence(words=['165', 'Saxton', 'St \xa0Glastonbury,', 'CT', '06033'], tags=['Address']),
#  LabeledSentence(words=['23', 'Oak', 'Valley', 'St \xa0Westport,', 'CT', '06880'], tags=['Address']),
#  LabeledSentence(words=['596', 'Livingston', 'Street\xa0Barrington,', 'IL', '60010'], tags=['Address']),
#  LabeledSentence(words=['8829', 'Cherry', 'Ave \xa0Saint', 'Augustine,', 'FL', '32084'], tags=['Address']),
#  LabeledSentence(words=['83', 'Sage', 'Drive\xa0Westbury,', 'NY', '11590'], tags=['Address']),
#  LabeledSentence(words=['7981', 'Wild', 'Horse', 'Street\xa0Northville,', 'MI', '48167'], tags=['Address']),
#  LabeledSentence(words=['992', 'Hilldale', 'Ave \xa0Ellicott', 'City,', 'MD', '21042'], tags=['Address']),
#  LabeledSentence(words=['703', 'East', 'Livingston', 'Lane\xa0Ft', 'Mitchell,', 'KY', '41017'], tags=['Address']),
#  LabeledSentence(words=['39', 'Atlantic', 'Lane\xa0Wappingers', 'Falls,', 'NY', '12590'], tags=['Address']),
#  LabeledSentence(words=['3', 'College', 'Court\xa0Calumet', 'City,', 'IL', '60409'], tags=['Address']),
#  LabeledSentence(words=['720', 'Wilson', 'Street\xa0Wilson,', 'NC', '27893'], tags=['Address']),
#  LabeledSentence(words=['63', 'W ', 'Hillside', 'St \xa0Perrysburg,', 'OH', '43551'], tags=['Address']),
#  LabeledSentence(words=['70', 'Green', 'Hill', 'Circle\xa0Peabody,', 'MA', '01960'], tags=['Address']),
#  LabeledSentence(words=['50', 'Woodside', 'Court\xa0Coram,', 'NY', '11727'], tags=['Address']),
#  LabeledSentence(words=['431', 'South', 'Spring', 'St \xa0Monroe,', 'NY', '10950'], tags=['Address']),
#  LabeledSentence(words=['7518', 'Cooper', 'Street\xa0Fort', 'Walton', 'Beach,', 'FL', '32547'], tags=['Address']),
#  LabeledSentence(words=['267', 'Laurel', 'Ave \xa0Bethlehem,', 'PA', '18015'], tags=['Address']),
#  LabeledSentence(words=['2', 'Marshall', 'Lane\xa0Lake', 'In', 'The', 'Hills,', 'IL', '60156'], tags=['Address']),
#  LabeledSentence(words=['53', 'Marconi', 'Lane\xa0Clifton,', 'NJ', '07011'], tags=['Address']),
#  LabeledSentence(words=['711', 'Wrangler', 'Ave \xa0Yonkers,', 'NY', '10701'], tags=['Address']),
#  LabeledSentence(words=['587', 'Howard', 'Ave \xa0Starkville,', 'MS', '39759'], tags=['Address']),
#  LabeledSentence(words=['8654', 'Shore', 'Ave \xa0Westwood,', 'NJ', '07675'], tags=['Address']),
#  LabeledSentence(words=['7476', 'Oakwood', 'Drive\xa0Coventry,', 'RI', '02816'], tags=['Address']),
#  LabeledSentence(words=['67', 'Jockey', 'Hollow', 'Drive\xa0Manassas,', 'VA', '20109'], tags=['Address']),
#  LabeledSentence(words=['6', 'Carriage', 'St \xa0Freehold,', 'NJ', '07728'], tags=['Address']),
#  LabeledSentence(words=['13', 'Division', 'St \xa0Kokomo,', 'IN', '46901'], tags=['Address']),
#  LabeledSentence(words=['957', 'County', 'Dr \xa0Clermont,', 'FL', '34711'], tags=['Address']),
#  LabeledSentence(words=['457', 'Bow', 'Ridge', 'St \xa0Collierville,', 'TN', '38017'], tags=['Address']),
#  LabeledSentence(words=['258', 'Summit', 'Circle\xa0Oak', 'Creek,', 'WI', '53154'], tags=['Address']),
#  LabeledSentence(words=['8662', 'Cross', 'Lane\xa0Richmond', 'Hill,', 'NY', '11418'], tags=['Address']),
#  LabeledSentence(words=['37', 'New', 'Saddle', 'Ave \xa0Greenfield,', 'IN', '46140'], tags=['Address']),
#  LabeledSentence(words=['7780', 'North', 'Lookout', 'Drive\xa0West', 'Des', 'Moines,', 'IA', '50265'], tags=['Address']),
#  LabeledSentence(words=['566', 'Glendale', 'Ave \xa0Boynton', 'Beach,', 'FL', '33435'], tags=['Address']),
#  LabeledSentence(words=['8444A', 'W ', 'Rose', 'Drive\xa0Worcester,', 'MA', '01604'], tags=['Address']),
#  LabeledSentence(words=['532', 'Lancaster', 'Street\xa0Oxon', 'Hill,', 'MD', '20745'], tags=['Address']),
#  LabeledSentence(words=['478', 'Wakehurst', 'St \xa0Olympia,', 'WA', '98512'], tags=['Address']),
#  LabeledSentence(words=['27', 'Ramblewood', 'Ave \xa0Edison,', 'NJ', '08817'], tags=['Address']),
#  LabeledSentence(words=['9484', 'Manchester', 'St \xa0Dickson,', 'TN', '37055'], tags=['Address']),
#  LabeledSentence(words=['8902', 'Canal', 'Street\xa0Daphne,', 'AL', '36526'], tags=['Address']),
#  LabeledSentence(words=['7931', 'West', 'Westminster', 'Street\xa0Lansing,', 'MI', '48910'], tags=['Address']),
#  LabeledSentence(words=['27', 'Redwood', 'Dr \xa0Chattanooga,', 'TN', '37421'], tags=['Address']),
#  LabeledSentence(words=['8934', 'Bradford', 'Street\xa0Janesville,', 'WI', '53546'], tags=['Address']),
#  LabeledSentence(words=['83', 'Edgemont', 'Ave \xa0Glen', 'Ellyn,', 'IL', '60137'], tags=['Address']),
#  LabeledSentence(words=['443', 'James', 'Dr \xa0Savage,', 'MN', '55378'], tags=['Address']),
#  LabeledSentence(words=['24', 'W ', 'Rockcrest', 'Street\xa0Goldsboro,', 'NC', '27530'], tags=['Address']),
#  LabeledSentence(words=['34', 'Coffee', 'Drive\xa0West', 'Haven,', 'CT', '06516'], tags=['Address']),
#  LabeledSentence(words=['1', 'Walt', 'Whitman', 'St \xa0Vienna,', 'VA', '22180'], tags=['Address']),
#  LabeledSentence(words=['64', 'Indian', 'Summer', 'Street\xa0Grandville,', 'MI', '49418'], tags=['Address']),
#  LabeledSentence(words=['875', 'Livingston', 'Dr \xa0Youngstown,', 'OH', '44512'], tags=['Address']),
#  LabeledSentence(words=['394', 'Lyme', 'Ave \xa0Philadelphia,', 'PA', '19111'], tags=['Address']),
#  LabeledSentence(words=['231', 'Parker', 'Drive\xa0Fort', 'Mill,', 'SC', '29708'], tags=['Address']),
#  LabeledSentence(words=['201', 'Trusel', 'St \xa0Commack,', 'NY', '11725'], tags=['Address']),
#  LabeledSentence(words=['69', 'West', 'Westport', 'Avenue\xa0Martinsville,', 'VA', '24112'], tags=['Address']),
#  LabeledSentence(words=['216', 'King', 'St \xa0Parlin,', 'NJ', '08859'], tags=['Address']),
#  LabeledSentence(words=['81', 'Virginia', 'Court\xa0Honolulu,', 'HI', '96815'], tags=['Address']),
#  LabeledSentence(words=['7036', 'Fairground', 'Ave \xa0Hyattsville,', 'MD', '20782'], tags=['Address']),
#  LabeledSentence(words=['71', 'South', 'Glenholme', 'Road\xa0Woodstock,', 'GA', '30188'], tags=['Address']),
#  LabeledSentence(words=['486', 'W ', 'Augusta', 'St \xa0Hillsboro,', 'OR', '97124'], tags=['Address']),
#  LabeledSentence(words=['8351', 'Winding', 'Way', 'Road\xa0Annapolis,', 'MD', '21401'], tags=['Address']),
#  LabeledSentence(words=['624', 'Lafayette', 'Ave \xa0Woonsocket,', 'RI', '02895'], tags=['Address']),
#  LabeledSentence(words=['8217', 'Honey', 'Creek', 'Street\xa0Sidney,', 'OH', '45365'], tags=['Address']),
#  LabeledSentence(words=['89', 'South', 'Ave \xa0Riverdale,', 'GA', '30274'], tags=['Address']),
#  LabeledSentence(words=['675', 'Marlborough', 'Street\xa0Sugar', 'Land,', 'TX', '77478'], tags=['Address']),
#  LabeledSentence(words=['7993', 'Applegate', 'Drive\xa0Silver', 'Spring,', 'MD', '20901'], tags=['Address']),
#  LabeledSentence(words=['8093', 'Fawn', 'Street\xa0Orange,', 'NJ', '07050'], tags=['Address']),
#  LabeledSentence(words=['318', 'Rock', 'Creek', 'Street\xa0La', 'Vergne,', 'TN', '37086'], tags=['Address']),
#  LabeledSentence(words=['8', 'Bald', 'Hill', 'St \xa0La', 'Crosse,', 'WI', '54601'], tags=['Address']),
#  LabeledSentence(words=['835', 'Glenlake', 'Drive\xa0Oak', 'Park,', 'MI', '48237'], tags=['Address']),
#  LabeledSentence(words=['728', 'Oakland', 'St \xa0Bel', 'Air,', 'MD', '21014'], tags=['Address']),
#  LabeledSentence(words=['388', 'West', 'Magnolia', 'Rd \xa0Knoxville,', 'TN', '37918'], tags=['Address']),
#  LabeledSentence(words=['9593', 'E ', 'Myrtle', 'St \xa0Superior,', 'WI', '54880'], tags=['Address']),
#  LabeledSentence(words=['9580', 'Grand', 'Street\xa0Waynesboro,', 'PA', '17268'], tags=['Address']),
#  LabeledSentence(words=['35', 'Birch', 'Hill', 'Street\xa0Yorktown', 'Heights,', 'NY', '10598'], tags=['Address']),
#  LabeledSentence(words=['47', 'East', 'Mountainview', 'Road\xa0Amarillo,', 'TX', '79106'], tags=['Address']),
#  LabeledSentence(words=['210', '1st', 'Street\xa0Midlothian,', 'VA', '23112'], tags=['Address']),
#  LabeledSentence(words=['274', '4th', 'Court\xa0Sun', 'Prairie,', 'WI', '53590'], tags=['Address']),
#  LabeledSentence(words=['419', 'Whitemarsh', 'Street\xa0Canton,', 'GA', '30114'], tags=['Address']),
#  LabeledSentence(words=['379', 'Gates', 'Dr \xa0Selden,', 'NY', '11784'], tags=['Address']),
#  LabeledSentence(words=['718', 'Liberty', 'Court\xa0Rock', 'Hill,', 'SC', '29730'], tags=['Address']),
#  LabeledSentence(words=['70', 'South', 'Holly', 'Court\xa0Grovetown,', 'GA', '30813'], tags=['Address']),
#  LabeledSentence(words=['5', 'Amherst', 'Drive\xa0Allen', 'Park,', 'MI', '48101'], tags=['Address']),
#  LabeledSentence(words=['316', 'Columbia', 'St \xa0New', 'Albany,', 'IN', '47150'], tags=['Address']),
#  LabeledSentence(words=['9', 'Myrtle', 'Road\xa0Lake', 'Charles,', 'LA', '70605'], tags=['Address']),
#  LabeledSentence(words=['408', 'W ', 'Marshall', 'Court\xa0Newburgh,', 'NY', '12550'], tags=['Address']),
#  LabeledSentence(words=['72', 'Hilltop', 'St \xa0Waterbury,', 'CT', '06705'], tags=['Address']),
#  LabeledSentence(words=['50', 'Airport', 'Rd \xa0Wausau,', 'WI', '54401'], tags=['Address']),
#  LabeledSentence(words=['4', '4th', 'Court\xa0Easley,', 'SC', '29640'], tags=['Address']),
#  LabeledSentence(words=['117', 'Center', 'Street\xa0Delray', 'Beach,', 'FL', '33445'], tags=['Address']),
#  LabeledSentence(words=['9104', 'Atlantic', 'Drive\xa0Lexington,', 'NC', '27292'], tags=['Address']),
#  LabeledSentence(words=['89', 'W ', 'Bedford', 'Road\xa0Upper', 'Darby,', 'PA', '19082'], tags=['Address']),
#  LabeledSentence(words=['815', 'S ', 'Walnut', 'Drive\xa0Germantown,', 'MD', '20874'], tags=['Address']),
#  LabeledSentence(words=['148', '4th', 'Avenue\xa0Asbury', 'Park,', 'NJ', '07712'], tags=['Address']),
#  LabeledSentence(words=['67', 'Buttonwood', 'Drive\xa0Fremont,', 'OH', '43420'], tags=['Address']),
#  LabeledSentence(words=['32', 'College', 'Street\xa0Levittown,', 'NY', '11756'], tags=['Address']),
#  LabeledSentence(words=['585', 'Bridle', 'Ave \xa0Snellville,', 'GA', '30039'], tags=['Address']),
#  LabeledSentence(words=['95', 'Nut', 'Swamp', 'Dr \xa0Jamaica,', 'NY', '11432'], tags=['Address']),
#  LabeledSentence(words=['3', 'Heather', 'Lane\xa0Desoto,', 'TX', '75115'], tags=['Address']),
#  LabeledSentence(words=['7989', 'Homewood', 'Dr \xa0Winder,', 'GA', '30680'], tags=['Address']),
#  LabeledSentence(words=['9708', 'North', 'Shub', 'Farm', 'Street\xa0Coatesville,', 'PA', '19320'], tags=['Address']),
#  LabeledSentence(words=['71', 'Grove', 'Dr \xa0San', 'Diego,', 'CA', '92111'], tags=['Address']),
#  LabeledSentence(words=['8006', 'Lake', 'Forest', 'Drive\xa0Tiffin,', 'OH', '44883'], tags=['Address']),
#  LabeledSentence(words=['44', 'Yukon', 'St \xa0Altoona,', 'PA', '16601'], tags=['Address']),
#  LabeledSentence(words=['321', 'Wilson', 'Ave \xa0Holyoke,', 'MA', '01040'], tags=['Address']),
#  LabeledSentence(words=['278', 'Manhattan', 'Court\xa0Englewood,', 'NJ', '07631'], tags=['Address']),
#  LabeledSentence(words=['8688', 'Highland', 'St \xa0Rocklin,', 'CA', '95677'], tags=['Address']),
#  LabeledSentence(words=['7828', 'Green', 'Street\xa0Lebanon,', 'PA', '17042'], tags=['Address']),
#  LabeledSentence(words=['64', 'Princeton', 'Street\xa0Dedham,', 'MA', '02026'], tags=['Address']),
#  LabeledSentence(words=['7758', 'Greystone', 'St \xa0Mankato,', 'MN', '56001'], tags=['Address']),
#  LabeledSentence(words=['14', 'Livingston', 'St \xa0Hartselle,', 'AL', '35640'], tags=['Address']),
#  LabeledSentence(words=['76', 'N ', 'Griffin', 'St \xa0Riverside,', 'NJ', '08075'], tags=['Address']),
#  LabeledSentence(words=['7127', 'Heritage', 'Lane\xa0Peoria,', 'IL', '61604'], tags=['Address']),
#  LabeledSentence(words=['72', 'Corona', 'Rd \xa0Newark,', 'NJ', '07103'], tags=['Address']),
#  LabeledSentence(words=['7587', 'Lincoln', 'Avenue\xa0Mcdonough,', 'GA', '30252'], tags=['Address']),
#  LabeledSentence(words=['4', 'Homestead', 'Street\xa0Greensburg,', 'PA', '15601'], tags=['Address']),
#  LabeledSentence(words=['271', 'N ', 'Marlborough', 'Ave \xa0Southampton,', 'PA', '18966'], tags=['Address']),
#  LabeledSentence(words=['133', 'Rockaway', 'Court\xa0Essex,', 'MD', '21221'], tags=['Address']),
#  LabeledSentence(words=['9706', 'Halifax', 'Road\xa0Lawrence', 'Township,', 'NJ', '08648'], tags=['Address']),
#  LabeledSentence(words=['955', 'East', 'Wall', 'Rd \xa0Grand', 'Blanc,', 'MI', '48439'], tags=['Address']),
#  LabeledSentence(words=['587', 'Bay', 'Meadows', 'Ave \xa0Deerfield,', 'IL', '60015'], tags=['Address']),
#  LabeledSentence(words=['811', 'Walnut', 'Street\xa0Lumberton,', 'NC', '28358'], tags=['Address']),
#  LabeledSentence(words=['11', 'Grand', 'Drive\xa0Port', 'Saint', 'Lucie,', 'FL', '34952'], tags=['Address']),
#  LabeledSentence(words=['981', 'Jones', 'St \xa0New', 'Port', 'Richey,', 'FL', '34653'], tags=['Address']),
#  LabeledSentence(words=['614', 'High', 'Noon', 'Lane\xa0Taunton,', 'MA', '02780'], tags=['Address']),
#  LabeledSentence(words=['200', 'Bishop', 'Drive\xa0Burnsville,', 'MN', '55337'], tags=['Address']),
#  LabeledSentence(words=['485', 'Wilson', 'Lane\xa0Mc', 'Lean,', 'VA', '22101'], tags=['Address']),
#  LabeledSentence(words=['7', 'SW ', 'Ohio', 'Lane\xa0Northbrook,', 'IL', '60062'], tags=['Address']),
#  LabeledSentence(words=['8376', 'Summit', 'Lane\xa0Phillipsburg,', 'NJ', '08865'], tags=['Address']),
#  LabeledSentence(words=['985', 'Princeton', 'Dr \xa0Bonita', 'Springs,', 'FL', '34135'], tags=['Address']),
#  LabeledSentence(words=['8', 'Pacific', 'Drive\xa0Staten', 'Island,', 'NY', '10301'], tags=['Address']),
#  LabeledSentence(words=['8011', 'South', 'Locust', 'Ave \xa0Bowling', 'Green,', 'KY', '42101'], tags=['Address']),
#  LabeledSentence(words=['8204', 'Sherwood', 'Court\xa0Fresh', 'Meadows,', 'NY', '11365'], tags=['Address']),
#  LabeledSentence(words=['185', 'Fieldstone', 'Lane\xa0New', 'Castle,', 'PA', '16101'], tags=['Address']),
#  LabeledSentence(words=['8037', 'Carriage', 'Lane\xa0Massapequa', 'Park,', 'NY', '11762'], tags=['Address']),
#  LabeledSentence(words=['86', 'Thomas', 'St \xa0Lititz,', 'PA', '17543'], tags=['Address']),
#  LabeledSentence(words=['9265', 'Olive', 'Street\xa0Odenton,', 'MD', '21113'], tags=['Address']),
#  LabeledSentence(words=['57', 'San', 'Carlos', 'Circle\xa0Elizabethton,', 'TN', '37643'], tags=['Address']),
#  LabeledSentence(words=['82', 'Walnutwood', 'Street\xa0Wheeling,', 'WV', '26003'], tags=['Address']),
#  LabeledSentence(words=['79', 'Kirkland', 'Ave \xa0Crawfordsville,', 'IN', '47933'], tags=['Address']),
#  LabeledSentence(words=['354', 'S ', 'Cleveland', 'Ave \xa0Santa', 'Cruz,', 'CA', '95060'], tags=['Address']),
#  LabeledSentence(words=['844', 'Woodsman', 'St \xa0Elizabeth', 'City,', 'NC', '27909'], tags=['Address']),
#  LabeledSentence(words=['8456', 'Saxon', 'Ave \xa0Mays', 'Landing,', 'NJ', '08330'], tags=['Address']),
#  LabeledSentence(words=['7306', '2nd', 'Street\xa0Perth', 'Amboy,', 'NJ', '08861'], tags=['Address']),
#  LabeledSentence(words=['5', 'Lakewood', 'St \xa0Burlington,', 'MA', '01803'], tags=['Address']),
#  LabeledSentence(words=['58', 'Fairview', 'Lane\xa0Vicksburg,', 'MS', '39180'], tags=['Address']),
#  LabeledSentence(words=['936', 'Hill', 'Street\xa0Meriden,', 'CT', '06450'], tags=['Address']),
#  LabeledSentence(words=['88', 'Orchard', 'St \xa0North', 'Fort', 'Myers,', 'FL', '33917'], tags=['Address']),
#  LabeledSentence(words=['23', 'Birch', 'Hill', 'Ave \xa0Englishtown,', 'NJ', '07726'], tags=['Address']),
#  LabeledSentence(words=['885', 'Catherine', 'St \xa0Pasadena,', 'MD', '21122'], tags=['Address']),
#  LabeledSentence(words=['83', 'Bohemia', 'Lane\xa0Belleville,', 'NJ', '07109'], tags=['Address']),
#  LabeledSentence(words=['158', 'Beacon', 'Circle\xa0Mchenry,', 'IL', '60050'], tags=['Address']),
#  LabeledSentence(words=['262', 'East', 'College', 'Drive\xa0Spring', 'Valley,', 'NY', '10977'], tags=['Address']),
#  LabeledSentence(words=['14', 'N ', 'Race', 'Lane\xa0Des', 'Plaines,', 'IL', '60016'], tags=['Address']),
#  LabeledSentence(words=['9364', 'Fifth', 'Rd \xa0Mount', 'Prospect,', 'IL', '60056'], tags=['Address']),
#  LabeledSentence(words=['33', 'Sussex', 'Court\xa0Battle', 'Creek,', 'MI', '49015'], tags=['Address']),
#  LabeledSentence(words=['26', 'Griffin', 'Drive\xa0Bayonne,', 'NJ', '07002'], tags=['Address']),
#  LabeledSentence(words=['8467', 'Edgewood', 'Street\xa0Upper', 'Marlboro,', 'MD', '20772'], tags=['Address']),
#  LabeledSentence(words=['603', 'W ', 'Clark', 'St \xa0Tonawanda,', 'NY', '14150'], tags=['Address']),
#  LabeledSentence(words=['122', 'Rockville', 'St \xa0Prior', 'Lake,', 'MN', '55372'], tags=['Address']),
#  LabeledSentence(words=['28', 'Rockledge', 'Street\xa0Lynchburg,', 'VA', '24502'], tags=['Address']),
#  LabeledSentence(words=['653', 'Glenwood', 'St \xa0Wadsworth,', 'OH', '44281'], tags=['Address']),
#  LabeledSentence(words=['198', 'N ', 'Mill', 'Pond', 'Rd \xa0Stockbridge,', 'GA', '30281'], tags=['Address']),
#  LabeledSentence(words=['8919', 'E ', 'Airport', 'Ave \xa0Dorchester', 'Center,', 'MA', '02124'], tags=['Address']),
#  LabeledSentence(words=['7482', 'St', 'Margarets', 'Road\xa0Fayetteville,', 'NC', '28303'], tags=['Address']),
#  LabeledSentence(words=['7878', 'Blackburn', 'Drive\xa0Kennewick,', 'WA', '99337'], tags=['Address']),
#  LabeledSentence(words=['931', 'Lancaster', 'St \xa0Muskego,', 'WI', '53150'], tags=['Address']),
#  LabeledSentence(words=['300', 'East', 'Pumpkin', 'Hill', 'Drive\xa0Chicago', 'Heights,', 'IL', '60411'], tags=['Address']),
#  LabeledSentence(words=['7369', 'W ', 'Smith', 'Street\xa0Flint,', 'MI', '48504'], tags=['Address']),
#  LabeledSentence(words=['646', 'Winchester', 'St \xa0Mount', 'Juliet,', 'TN', '37122'], tags=['Address']),
#  LabeledSentence(words=['7487', 'Shipley', 'Lane\xa0New', 'Baltimore,', 'MI', '48047'], tags=['Address']),
#  LabeledSentence(words=['433', 'N ', 'Summit', 'Drive\xa0Marcus', 'Hook,', 'PA', '19061'], tags=['Address']),
#  LabeledSentence(words=['38', 'George', 'Drive\xa0Tacoma,', 'WA', '98444'], tags=['Address']),
#  LabeledSentence(words=['532', 'Pendergast', 'Ave \xa0Casselberry,', 'FL', '32707'], tags=['Address']),
#  LabeledSentence(words=['553', 'Bald', 'Hill', 'Dr \xa0North', 'Brunswick,', 'NJ', '08902'], tags=['Address']),
#  LabeledSentence(words=['17', 'Smith', 'Store', 'Road\xa0Sykesville,', 'MD', '21784'], tags=['Address']),
#  LabeledSentence(words=['591', 'Proctor', 'Drive\xa0West', 'Bend,', 'WI', '53095'], tags=['Address']),
#  LabeledSentence(words=['838', 'Wild', 'Horse', 'St \xa0Lakeland,', 'FL', '33801'], tags=['Address']),
#  LabeledSentence(words=['971', 'Ridgeview', 'Rd \xa0Garfield,', 'NJ', '07026'], tags=['Address']),
#  LabeledSentence(words=['769', 'Sleepy', 'Hollow', 'Lane\xa0Muncie,', 'IN', '47302'], tags=['Address']),
#  LabeledSentence(words=['8385', 'Tanglewood', 'Court\xa0Newington,', 'CT', '06111'], tags=['Address']),
#  LabeledSentence(words=['9', 'Kirkland', 'Street\xa0Lockport,', 'NY', '14094'], tags=['Address']),
#  LabeledSentence(words=['479', 'Joy', 'Ridge', 'Rd \xa0Mansfield,', 'MA', '02048'], tags=['Address']),
#  LabeledSentence(words=['650', 'Country', 'Street\xa0Saint', 'Johns,', 'FL', '32259'], tags=['Address']),
#  LabeledSentence(words=['2', 'Harvey', 'Lane\xa0Midland,', 'MI', '48640'], tags=['Address']),
#  LabeledSentence(words=['972', 'South', 'Marshall', 'Ave \xa0Elizabeth,', 'NJ', '07202'], tags=['Address']),
#  LabeledSentence(words=['353', 'Sussex', 'Street\xa0Stuart,', 'FL', '34997'], tags=['Address']),
#  LabeledSentence(words=['921', 'Old', 'Greystone', 'Road\xa0Medford,', 'MA', '02155'], tags=['Address']),
#  LabeledSentence(words=['8581', 'Sunnyslope', 'St \xa0Lincoln,', 'NE', '68506'], tags=['Address']),
#  LabeledSentence(words=['356', 'Old', 'York', 'Lane\xa0Woodhaven,', 'NY', '11421'], tags=['Address']),
#  LabeledSentence(words=['9973', 'Charles', 'Drive\xa0Villa', 'Park,', 'IL', '60181'], tags=['Address']),
#  LabeledSentence(words=['7459', 'Greenview', 'Dr \xa0Potomac,', 'MD', '20854'], tags=['Address']),
#  LabeledSentence(words=['5', 'Bellevue', 'Ave \xa0Des', 'Moines,', 'IA', '50310'], tags=['Address']),
#  LabeledSentence(words=['48', 'Rock', 'Maple', 'St \xa0Hanover', 'Park,', 'IL', '60133'], tags=['Address']),
#  LabeledSentence(words=['9554', 'Shadow', 'Brook', 'Avenue\xa0Strongsville,', 'OH', '44136'], tags=['Address']),
#  LabeledSentence(words=['224', 'Miller', 'Road\xa0Butler,', 'PA', '16001'], tags=['Address']),
#  LabeledSentence(words=['95', 'Hawthorne', 'Street\xa0Naples,', 'FL', '34116'], tags=['Address']),
#  LabeledSentence(words=['7859', 'North', 'Princess', 'St \xa0Berwyn,', 'IL', '60402'], tags=['Address']),
#  LabeledSentence(words=['8471', 'East', 'Drive\xa0San', 'Lorenzo,', 'CA', '94580'], tags=['Address']),
#  LabeledSentence(words=['7464', 'Clay', 'Court\xa0Newtown,', 'PA', '18940'], tags=['Address']),
#  LabeledSentence(words=['723', 'South', 'Dr \xa0Morton', 'Grove,', 'IL', '60053'], tags=['Address']),
#  LabeledSentence(words=['4', 'Blue', 'Spring', 'Street\xa0Mebane,', 'NC', '27302'], tags=['Address']),
#  LabeledSentence(words=['508', 'Bank', 'St \xa0Princeton,', 'NJ', '08540'], tags=['Address']),
#  LabeledSentence(words=['538', 'Mountainview', 'Street\xa0Highland', 'Park,', 'IL', '60035'], tags=['Address']),
#  LabeledSentence(words=['8840', 'Addison', 'Drive\xa0Clemmons,', 'NC', '27012'], tags=['Address']),
#  LabeledSentence(words=['512', 'North', 'Brook', 'Road\xa0Union', 'City,', 'NJ', '07087'], tags=['Address']),
#  LabeledSentence(words=['7', 'Thompson', 'Court\xa0Indianapolis,', 'IN', '46201'], tags=['Address']),
#  LabeledSentence(words=['97', 'Glenridge', 'Dr \xa0Upland,', 'CA', '91784'], tags=['Address']),
#  LabeledSentence(words=['6', 'St', 'Margarets', 'Court\xa0Aiken,', 'SC', '29803'], tags=['Address']),
#  LabeledSentence(words=['55', 'Creekside', 'Street\xa0Enfield,', 'CT', '06082'], tags=['Address']),
#  LabeledSentence(words=['8092', 'Grandrose', 'Ave \xa0Fairfield,', 'CT', '06824'], tags=['Address']),
#  LabeledSentence(words=['950', 'Tanglewood', 'St \xa0Cleveland,', 'TN', '37312'], tags=['Address']),
#  LabeledSentence(words=['9990', 'Lantern', 'Drive\xa0East', 'Elmhurst,', 'NY', '11369'], tags=['Address']),
#  LabeledSentence(words=['601', 'Jefferson', 'Drive\xa0Hickory,', 'NC', '28601'], tags=['Address']),
#  LabeledSentence(words=['440', 'Bow', 'Ridge', 'St \xa0Holly', 'Springs,', 'NC', '27540'], tags=['Address']),
#  LabeledSentence(words=['7357', 'Winchester', 'Drive\xa0Fairfax,', 'VA', '22030'], tags=['Address']),
#  LabeledSentence(words=['419', 'Greenview', 'Ave \xa0North', 'Augusta,', 'SC', '29841'], tags=['Address']),
#  LabeledSentence(words=['8701', 'Magnolia', 'St \xa0Seattle,', 'WA', '98144'], tags=['Address']),
#  LabeledSentence(words=['124', 'Smith', 'Store', 'Ave \xa0Tallahassee,', 'FL', '32303'], tags=['Address']),
#  LabeledSentence(words=['75', 'Greenrose', 'Street\xa0Cartersville,', 'GA', '30120'], tags=['Address']),
#  LabeledSentence(words=['8976', 'Circle', 'St \xa0Norcross,', 'GA', '30092'], tags=['Address']),
#  LabeledSentence(words=['7178', 'Shady', 'St \xa0Uniondale,', 'NY', '11553'], tags=['Address']),
#  LabeledSentence(words=['73', 'Orange', 'Road\xa0Davenport,', 'IA', '52804'], tags=['Address']),
#  LabeledSentence(words=['392', 'Whitemarsh', 'Lane\xa0Grosse', 'Pointe,', 'MI', '48236'], tags=['Address']),
#  LabeledSentence(words=['8413', 'Brandywine', 'Lane\xa0Zion,', 'IL', '60099'], tags=['Address']),
#  LabeledSentence(words=['16', 'Gonzales', 'St \xa0West', 'Chicago,', 'IL', '60185'], tags=['Address']),
#  LabeledSentence(words=['259', 'Warren', 'Dr \xa0North', 'Miami', 'Beach,', 'FL', '33160'], tags=['Address']),
#  LabeledSentence(words=['19', 'Brickyard', 'Rd \xa0Deerfield', 'Beach,', 'FL', '33442'], tags=['Address']),
#  LabeledSentence(words=['434', 'Greenrose', 'Avenue\xa0Harvey,', 'IL', '60426'], tags=['Address']),
#  LabeledSentence(words=['447', 'Fairfield', 'Lane\xa0Clarksville,', 'TN', '37040'], tags=['Address']),
#  LabeledSentence(words=['8460', 'S ', 'Hillside', 'Avenue\xa0Brandon,', 'FL', '33510'], tags=['Address']),
#  LabeledSentence(words=['7485', 'High', 'Noon', 'Drive\xa0Galloway,', 'OH', '43119'], tags=['Address']),
#  LabeledSentence(words=['44', 'Riverview', 'Road\xa0Irwin,', 'PA', '15642'], tags=['Address']),
#  LabeledSentence(words=['9468', 'Brickell', 'Court\xa0Chicopee,', 'MA', '01020'], tags=['Address']),
#  LabeledSentence(words=['7679', 'Oakland', 'St \xa0Laurel,', 'MD', '20707'], tags=['Address']),
#  LabeledSentence(words=['67', 'Marlborough', 'Dr \xa0Menomonee', 'Falls,', 'WI', '53051'], tags=['Address']),
#  LabeledSentence(words=['9561', 'Mountainview', 'Road\xa0Latrobe,', 'PA', '15650'], tags=['Address']),
#  LabeledSentence(words=['8305', 'Thorne', 'Lane\xa0Reno,', 'NV', '89523'], tags=['Address']),
#  LabeledSentence(words=['9597', 'NW ', 'Harrison', 'Rd \xa0Findlay,', 'OH', '45840'], tags=['Address']),
#  LabeledSentence(words=['319', 'Greystone', 'Ave \xa0Cranberry', 'Twp,', 'PA', '16066'], tags=['Address']),
#  LabeledSentence(words=['324', 'Park', 'Street\xa0Glendora,', 'CA', '91740'], tags=['Address']),
#  LabeledSentence(words=['9386', 'Illinois', 'Road\xa0Westford,', 'MA', '01886'], tags=['Address']),
#  LabeledSentence(words=['9025', 'South', 'Walt', 'Whitman', 'Avenue\xa0Shrewsbury,', 'MA', '01545'], tags=['Address']),
#  LabeledSentence(words=['542', 'N ', 'Clinton', 'St \xa0Sacramento,', 'CA', '95820'], tags=['Address']),
#  LabeledSentence(words=['8736', 'Grand', 'St \xa0Eden', 'Prairie,', 'MN', '55347'], tags=['Address']),
#  LabeledSentence(words=['199', 'Foxrun', 'Drive\xa0Bear,', 'DE', '19701'], tags=['Address']),
#  LabeledSentence(words=['872', 'Bishop', 'St \xa0Campbell,', 'CA', '95008'], tags=['Address']),
#  LabeledSentence(words=['271', 'Plumb', 'Branch', 'Road\xa0Miami,', 'FL', '33125'], tags=['Address']),
#  LabeledSentence(words=['7809', 'S ', 'Pheasant', 'Court\xa0Fairmont,', 'WV', '26554'], tags=['Address']),
#  LabeledSentence(words=['52', 'Clinton', 'Rd \xa0Addison,', 'IL', '60101'], tags=['Address']),
#  LabeledSentence(words=['187', 'Thatcher', 'St \xa0Royersford,', 'PA', '19468'], tags=['Address']),
#  LabeledSentence(words=['9', 'Miles', 'St \xa0East', 'Meadow,', 'NY', '11554'], tags=['Address']),
#  LabeledSentence(words=['17', 'West', 'Griffin', 'Ave \xa0Everett,', 'MA', '02149'], tags=['Address']),
#  LabeledSentence(words=['7605', 'Border', 'Rd \xa0Ottawa,', 'IL', '61350'], tags=['Address']),
#  LabeledSentence(words=['91', 'Highland', 'St \xa0Pueblo,', 'CO', '81001'], tags=['Address']),
#  LabeledSentence(words=['9380', 'Rockledge', 'Street\xa0Lincolnton,', 'NC', '28092'], tags=['Address']),
#  LabeledSentence(words=['91', 'West', 'Grandrose', 'Avenue\xa0North', 'Kingstown,', 'RI', '02852'], tags=['Address']),
#  LabeledSentence(words=['387', 'Howard', 'St \xa0Sewell,', 'NJ', '08080'], tags=['Address']),
#  LabeledSentence(words=['934', 'Cleveland', 'St \xa0Capitol', 'Heights,', 'MD', '20743'], tags=['Address']),
#  LabeledSentence(words=['9041', 'NE ', 'Acacia', 'Drive\xa0Waukegan,', 'IL', '60085'], tags=['Address']),
#  LabeledSentence(words=['80', 'Wagon', 'St \xa0Canonsburg,', 'PA', '15317'], tags=['Address']),
#  LabeledSentence(words=['987', 'South', 'Front', 'Rd \xa0Lanham,', 'MD', '20706'], tags=['Address']),
#  LabeledSentence(words=['7706', 'Pearl', 'Circle\xa0Fitchburg,', 'MA', '01420'], tags=['Address']),
#  LabeledSentence(words=['15', 'E ', 'Prospect', 'Ave \xa0Butte,', 'MT', '59701'], tags=['Address']),
#  LabeledSentence(words=['86', 'Greenrose', 'Drive\xa0Cherry', 'Hill,', 'NJ', '08003'], tags=['Address']),
#  LabeledSentence(words=['9324', 'Fairground', 'Ave \xa0Jeffersonville,', 'IN', '47130'], tags=['Address']),
#  LabeledSentence(words=['140', 'Honey', 'Creek', 'Dr \xa0Morganton,', 'NC', '28655'], tags=['Address']),
#  LabeledSentence(words=['8044', 'Southampton', 'Street\xa0Eastlake,', 'OH', '44095'], tags=['Address']),
#  LabeledSentence(words=['9676', 'Edgewater', 'Ave \xa0Mooresville,', 'NC', '28115'], tags=['Address']),
#  LabeledSentence(words=['8', 'Canal', 'Ave \xa0Virginia', 'Beach,', 'VA', '23451'], tags=['Address']),
#  LabeledSentence(words=['9964', 'Summit', 'Street\xa0Schererville,', 'IN', '46375'], tags=['Address']),
#  LabeledSentence(words=['90', 'Devonshire', 'Avenue\xa0Ithaca,', 'NY', '14850'], tags=['Address']),
#  LabeledSentence(words=['9603', 'Tower', 'Road\xa0Willingboro,', 'NJ', '08046'], tags=['Address']),
#  LabeledSentence(words=['272', 'Foster', 'St \xa0Nashville,', 'TN', '37205'], tags=['Address']),
#  LabeledSentence(words=['40', 'Garden', 'Ave \xa0Waukesha,', 'WI', '53186'], tags=['Address']),
#  LabeledSentence(words=['219', 'Amherst', 'Ave \xa0Windermere,', 'FL', '34786'], tags=['Address']),
#  LabeledSentence(words=['7071', 'E ', '8th', 'St \xa0Bethesda,', 'MD', '20814'], tags=['Address']),
#  LabeledSentence(words=['554', 'Sutor', 'Ave \xa0Graham,', 'NC', '27253'], tags=['Address']),
#  LabeledSentence(words=['101', 'Augusta', 'Court\xa0Cedar', 'Rapids,', 'IA', '52402'], tags=['Address']),
#  LabeledSentence(words=['970', 'George', 'Ave \xa0Piqua,', 'OH', '45356'], tags=['Address']),
#  LabeledSentence(words=['8125', 'Wild', 'Rose', 'Ave \xa0Palm', 'City,', 'FL', '34990'], tags=['Address']),
#  LabeledSentence(words=['222', 'Bradford', 'Dr \xa0Shepherdsville,', 'KY', '40165'], tags=['Address']),
#  LabeledSentence(words=['7562', 'Carriage', 'Lane\xa0Flowery', 'Branch,', 'GA', '30542'], tags=['Address']),
#  LabeledSentence(words=['53', 'Brickell', 'Lane\xa0Jackson,', 'NJ', '08527'], tags=['Address']),
#  LabeledSentence(words=['238', 'South', 'Queen', 'Street\xa0Apopka,', 'FL', '32703'], tags=['Address']),
#  LabeledSentence(words=['537', 'Bayberry', 'Ave \xa0Hopewell,', 'VA', '23860'], tags=['Address']),
#  LabeledSentence(words=['9256', 'Winchester', 'Street\xa0North', 'Royalton,', 'OH', '44133'], tags=['Address']),
#  LabeledSentence(words=['95', 'Fairfield', 'St \xa0Frankfort,', 'KY', '40601'], tags=['Address']),
#  LabeledSentence(words=['61', 'Piper', 'Lane\xa0Culpeper,', 'VA', '22701'], tags=['Address']),
#  LabeledSentence(words=['7782', 'Wrangler', 'Dr \xa0Sicklerville,', 'NJ', '08081'], tags=['Address']),
#  LabeledSentence(words=['77', 'South', 'Beacon', 'Street\xa0Omaha,', 'NE', '68107'], tags=['Address']),
#  LabeledSentence(words=['371', 'Gartner', 'Dr \xa0Amityville,', 'NY', '11701'], tags=['Address']),
#  LabeledSentence(words=['7', 'Pacific', 'Drive\xa0Orland', 'Park,', 'IL', '60462'], tags=['Address']),
#  LabeledSentence(words=['9557', 'Arch', 'Ave \xa0Stillwater,', 'MN', '55082'], tags=['Address']),
#  LabeledSentence(words=['70', 'Edgewood', 'St \xa0Rowlett,', 'TX', '75088'], tags=['Address']),
#  LabeledSentence(words=['7379', 'South', 'Cardinal', 'Court\xa0Londonderry,', 'NH', '03053'], tags=['Address']),
#  LabeledSentence(words=['46', 'Washington', 'Street\xa0Rocky', 'Mount,', 'NC', '27804'], tags=['Address']),
#  LabeledSentence(words=['9368', 'Hawthorne', 'Drive\xa0Fort', 'Lauderdale,', 'FL', '33308'], tags=['Address']),
#  LabeledSentence(words=['615', 'Philmont', 'St \xa0Elgin,', 'IL', '60120'], tags=['Address']),
#  LabeledSentence(words=['8977', 'Foxrun', 'Rd \xa0Sun', 'City,', 'AZ', '85351'], tags=['Address']),
#  LabeledSentence(words=['9109', 'North', 'Brown', 'Drive\xa0Skokie,', 'IL', '60076'], tags=['Address']),
#  LabeledSentence(words=['781', 'South', 'Yukon', 'Lane\xa0Oxford,', 'MS', '38655'], tags=['Address']),
#  LabeledSentence(words=['485', 'West', 'Walnutwood', 'St \xa0Wethersfield,', 'CT', '06109'], tags=['Address']),
#  LabeledSentence(words=['560', 'Cedar', 'Swamp', 'Street\xa0Emporia,', 'KS', '66801'], tags=['Address']),
#  LabeledSentence(words=['8826', 'Pulaski', 'Ave \xa0Mokena,', 'IL', '60448'], tags=['Address']),
#  LabeledSentence(words=['7166', 'Constitution', 'Dr \xa0Kissimmee,', 'FL', '34741'], tags=['Address']),
#  LabeledSentence(words=['7493', 'Marvon', 'St \xa0Griffin,', 'GA', '30223'], tags=['Address']),
#  LabeledSentence(words=['7269', 'Newcastle', 'Circle\xa0Ypsilanti,', 'MI', '48197'], tags=['Address']),
#  LabeledSentence(words=['95', 'Princess', 'Rd \xa0Auburndale,', 'FL', '33823'], tags=['Address']),
#  LabeledSentence(words=['200', 'San', 'Pablo', 'Court\xa0Cordova,', 'TN', '38016'], tags=['Address']),
#  LabeledSentence(words=['425', 'Magnolia', 'Rd \xa0Dearborn,', 'MI', '48124'], tags=['Address']),
#  LabeledSentence(words=['7583', 'Monroe', 'Street\xa0Lynn,', 'MA', '01902'], tags=['Address']),
#  LabeledSentence(words=['12', 'Military', 'Rd \xa0East', 'Lansing,', 'MI', '48823'], tags=['Address']),
#  LabeledSentence(words=['61', 'Rock', 'Maple', 'Street\xa0Spring', 'Hill,', 'FL', '34608'], tags=['Address']),
#  LabeledSentence(words=['882', 'W ', 'Railroad', 'Street\xa0Hinesville,', 'GA', '31313'], tags=['Address']),
#  LabeledSentence(words=['7', 'Buckingham', 'Court\xa0Elizabethtown,', 'PA', '17022'], tags=['Address']),
#  LabeledSentence(words=['9', 'Coffee', 'Drive\xa0Bloomington,', 'IN', '47401'], tags=['Address']),
#  LabeledSentence(words=['10', 'E ', 'Prince', 'St \xa0Palm', 'Beach', 'Gardens,', 'FL', '33410'], tags=['Address']),
#  LabeledSentence(words=['270', 'N ', 'Green', 'Hill', 'Ave \xa0Hummelstown,', 'PA', '17036'], tags=['Address']),
#  LabeledSentence(words=['217', 'Iroquois', 'Avenue\xa0Defiance,', 'OH', '43512'], tags=['Address']),
#  LabeledSentence(words=['95', 'Mayfair', 'Avenue\xa0State', 'College,', 'PA', '16801'], tags=['Address']),
#  LabeledSentence(words=['847', 'SE ', 'Golden', 'Star', 'Lane\xa0Riverview,', 'FL', '33569'], tags=['Address']),
#  LabeledSentence(words=['8317', 'Silver', 'Spear', 'St \xa0Camas,', 'WA', '98607'], tags=['Address']),
#  LabeledSentence(words=['386', 'Bald', 'Hill', 'St \xa0Romulus,', 'MI', '48174'], tags=['Address']),
#  LabeledSentence(words=['41', 'Vine', 'Street\xa0Richmond,', 'VA', '23223'], tags=['Address']),
#  LabeledSentence(words=['7964', 'Adams', 'Lane\xa0Lawndale,', 'CA', '90260'], tags=['Address']),
#  LabeledSentence(words=['68', 'Wentworth', 'St \xa0Sterling,', 'VA', '20164'], tags=['Address']),
#  LabeledSentence(words=['46', 'Race', 'St \xa0Natick,', 'MA', '01760'], tags=['Address']),
#  LabeledSentence(words=['31', 'Holly', 'Street\xa0Summerfield,', 'FL', '34491'], tags=['Address']),
#  LabeledSentence(words=['725', 'North', 'Logan', 'Drive\xa0Niagara', 'Falls,', 'NY', '14304'], tags=['Address']),
#  LabeledSentence(words=['737', 'West', 'Livingston', 'Drive\xa0Libertyville,', 'IL', '60048'], tags=['Address']),
#  LabeledSentence(words=['4', 'George', 'Ave \xa0Rosemount,', 'MN', '55068'], tags=['Address']),
#  LabeledSentence(words=['7794', 'Hudson', 'St \xa0Shirley,', 'NY', '11967'], tags=['Address']),
#  LabeledSentence(words=['9251', 'Roberts', 'Ave \xa0Holland,', 'MI', '49423'], tags=['Address']),
#  LabeledSentence(words=['61', 'Old', 'York', 'Ave \xa0Mesa,', 'AZ', '85203'], tags=['Address']),
#  LabeledSentence(words=['9356', 'North', 'Division', 'Lane\xa0Pickerington,', 'OH', '43147'], tags=['Address']),
#  LabeledSentence(words=['494', 'Carpenter', 'Lane\xa0East', 'Haven,', 'CT', '06512'], tags=['Address']),
#  LabeledSentence(words=['8369', 'Bohemia', 'Avenue\xa0Yorktown,', 'VA', '23693'], tags=['Address']),
#  LabeledSentence(words=['625', 'Littleton', 'Street\xa0Mount', 'Vernon,', 'NY', '10550'], tags=['Address']),
#  LabeledSentence(words=['495', 'Tunnel', 'Street\xa0Cranston,', 'RI', '02920'], tags=['Address']),
#  LabeledSentence(words=['112', 'South', 'Warren', 'Street\xa0Glen', 'Burnie,', 'MD', '21060'], tags=['Address']),
#  LabeledSentence(words=['77', 'Winchester', 'Drive\xa0Middletown,', 'CT', '06457'], tags=['Address']),
#  LabeledSentence(words=['14', 'Glenwood', 'St \xa0Suite', '199\xa0'], tags=['Address']),
#  LabeledSentence(words=['Buffalo', 'Grove,', 'IL', '60089575', 'Prospect', 'Avenue\xa0'], tags=['Address']),
#  LabeledSentence(words=['Danville,', 'VA', '245407223', 'Pilgrim', 'Rd \xa0'], tags=['Address']),
#  LabeledSentence(words=['Durham,', 'NC', '277038278', 'West', 'Ryan', 'Drive\xa0'], tags=['Address']),
#  LabeledSentence(words=['Thibodaux,', 'LA', '70301303', 'Hamilton', 'Avenue\xa0'], tags=['Address']),
#  LabeledSentence(words=['Paducah,', 'KY', '4200188', 'Spring', 'Road\xa0'], tags=['Address']),
#  LabeledSentence(words=['Syosset,', 'NY', '1179130', 'Williams', 'Lane\xa0'], tags=['Address']),
#  LabeledSentence(words=['Ellenwood,', 'GA', '30294666', 'Linda', 'Ave \xa0'], tags=['Address']),
#  LabeledSentence(words=['Dubuque,', 'IA', '520019415', 'Grandrose', 'Ave \xa0'], tags=['Address']),
#  LabeledSentence(words=['Montgomery', 'Village,', 'MD', '20886512', 'Manor', 'St \xa0'], tags=['Address']),
#  LabeledSentence(words=['North', 'Canton,', 'OH', '44720332', 'Sulphur', 'Springs', 'Lane\xa0'], tags=['Address']),
#  LabeledSentence(words=['Lake', 'Villa,', 'IL', '6004693', 'Old', 'Rocky', 'River', 'Dr \xa0'], tags=['Address']),
#  LabeledSentence(words=['Alexandria,', 'VA', '22304988', 'James', 'Street\xa0'], tags=['Address']),
#  LabeledSentence(words=['Delaware,', 'OH', '430158186', 'Ohio', 'St \xa0'], tags=['Address']),
#  LabeledSentence(words=['Onalaska,', 'WI', '54650695', 'Wrangler', 'Rd \xa0'], tags=['Address']),
#  LabeledSentence(words=['Suite', '4\xa0Maumee,', 'OH', '43537'], tags=['Address']),
#  LabeledSentence(words=['949', 'Country', 'Street\xa0Sandusky,', 'OH', '44870'], tags=['Address']),
#  LabeledSentence(words=['9664', 'Roehampton', 'Ave \xa0Elmont,', 'NY', '11003'], tags=['Address']),
#  LabeledSentence(words=['497', 'Summit', 'St \xa0Massillon,', 'OH', '44646'], tags=['Address']),
#  LabeledSentence(words=['699', 'West', 'Peg', 'Shop', 'St \xa0Kent,', 'OH', '44240'], tags=['Address']),
#  LabeledSentence(words=['540', 'Hudson', 'St \xa0New', 'Britain,', 'CT', '06051'], tags=['Address']),
#  LabeledSentence(words=['218', 'High', 'Point', 'Ave \xa0Paterson,', 'NJ', '07501'], tags=['Address']),
#  LabeledSentence(words=['27', 'Nichols', 'St \xa0Vernon', 'Rockville,', 'CT', '06066'], tags=['Address']),
#  LabeledSentence(words=['35', 'SE ', 'Canterbury', 'Drive\xa0Cornelius,', 'NC', '28031'], tags=['Address']),
#  LabeledSentence(words=['356', 'Cobblestone', 'Lane\xa0Suitland,', 'MD', '20746'], tags=['Address']),
#  LabeledSentence(words=['8371', 'Thatcher', 'Rd \xa0Mobile,', 'AL', '36605'], tags=['Address']),
#  LabeledSentence(words=['8206', 'School', 'Dr \xa0King', 'Of', 'Prussia,', 'PA', '19406'], tags=['Address']),
#  LabeledSentence(words=['518', 'Bear', 'Hill', 'Ave \xa0Clifton', 'Park,', 'NY', '12065'], tags=['Address']),
#  LabeledSentence(words=['8343', 'Bow', 'Ridge', 'Rd \xa0Chapel', 'Hill,', 'NC', '27516'], tags=['Address']),
#  LabeledSentence(words=['38', 'Border', 'Court\xa0La', 'Porte,', 'IN', '46350'], tags=['Address']),
#  LabeledSentence(words=['51', 'Roehampton', 'Avenue\xa0South', 'Richmond', 'Hill,', 'NY', '11419'], tags=['Address']),
#  LabeledSentence(words=['7734', 'Eagle', 'St \xa0Kaukauna,', 'WI', '54130'], tags=['Address']),
#  LabeledSentence(words=['90', 'Cottage', 'St \xa0Merrimack,', 'NH', '03054'], tags=['Address']),
#  LabeledSentence(words=['12C', 'Longbranch', 'Street\xa0Depew,', 'NY', '14043'], tags=['Address']),
#  LabeledSentence(words=['721', 'W ', 'Shipley', 'Lane\xa0Statesville,', 'NC', '28625'], tags=['Address']),
#  LabeledSentence(words=['779', 'S ', 'Maiden', 'Street\xa0Ada,', 'OK', '74820'], tags=['Address']),
#  LabeledSentence(words=['56', 'S ', 'Penn', 'St \xa0Bellmore,', 'NY', '11710'], tags=['Address']),
#  LabeledSentence(words=['6', 'S ', 'Littleton', 'Road\xa0Rosedale,', 'NY', '11422'], tags=['Address']),
#  LabeledSentence(words=['8', 'Brandywine', 'Court\xa0Carrollton,', 'GA', '30117'], tags=['Address']),
#  LabeledSentence(words=['107', 'SE ', 'Monroe', 'Street\xa0Circle', 'Pines,', 'MN', '55014'], tags=['Address']),
#  LabeledSentence(words=['713', 'S ', 'Durham', 'Court\xa0Hixson,', 'TN', '37343'], tags=['Address']),
#  LabeledSentence(words=['534', 'East', 'River', 'Dr \xa0Danbury,', 'CT', '06810'], tags=['Address']),
#  LabeledSentence(words=['59', 'South', 'Lookout', 'Street\xa0Fleming', 'Island,', 'FL', '32003'], tags=['Address']),
#  LabeledSentence(words=['335', 'East', 'Dr \xa0Chester,', 'PA', '19013'], tags=['Address']),
#  LabeledSentence(words=['358', 'Heather', 'Drive\xa0Avon', 'Lake,', 'OH', '44012'], tags=['Address']),
#  LabeledSentence(words=['9477', 'Marconi', 'Lane\xa0Fullerton,', 'CA', '92831'], tags=['Address']),
#  LabeledSentence(words=['9733', 'Lawrence', 'Lane\xa0West', 'Hempstead,', 'NY', '11552'], tags=['Address']),
#  LabeledSentence(words=['42', 'Logan', 'Circle\xa0Westlake,', 'OH', '44145'], tags=['Address']),
#  LabeledSentence(words=['586', 'Leeton', 'Ridge', 'Court\xa0Leesburg,', 'VA', '20175'], tags=['Address']),
#  LabeledSentence(words=['376', 'Glen', 'Ridge', 'Avenue\xa0Williamsport,', 'PA', '17701'], tags=['Address']),
#  LabeledSentence(words=['15', 'Cardinal', 'St \xa0Painesville,', 'OH', '44077'], tags=['Address']),
#  LabeledSentence(words=['8308', 'Pendergast', 'St \xa0Bedford,', 'OH', '44146'], tags=['Address']),
#  LabeledSentence(words=['36', 'Warren', 'Avenue\xa0Hallandale,', 'FL', '33009'], tags=['Address']),
#  LabeledSentence(words=['9245', 'Birchpond', 'Ave \xa0Alliance,', 'OH', '44601'], tags=['Address']),
#  LabeledSentence(words=['97', 'Linda', 'Ave \xa0Wake', 'Forest,', 'NC', '27587'], tags=['Address']),
#  LabeledSentence(words=['794', 'Cobblestone', 'Court\xa0Pompano', 'Beach,', 'FL', '33060'], tags=['Address']),
#  LabeledSentence(words=['8338', 'Sunnyslope', 'Street\xa0North', 'Ridgeville,', 'OH', '44039'], tags=['Address']),
#  LabeledSentence(words=['545', 'Harrison', 'Ave \xa0West', 'Orange,', 'NJ', '07052'], tags=['Address']),
#  LabeledSentence(words=['70', 'Andover', 'Street\xa0Valdosta,', 'GA', '31601'], tags=['Address']),
#  LabeledSentence(words=['7877', 'Queen', 'Ave \xa0Absecon,', 'NJ', '08205'], tags=['Address']),
#  LabeledSentence(words=['8960', 'Glen', 'Ridge', 'Court\xa0Crystal', 'Lake,', 'IL', '60014'], tags=['Address']),
#  LabeledSentence(words=['8526', 'Pin', 'Oak', 'Drive\xa0Nashua,', 'NH', '03060'], tags=['Address']),
#  LabeledSentence(words=['8749', 'E ', 'Manor', 'Drive\xa0Watertown,', 'MA', '02472'], tags=['Address']),
#  LabeledSentence(words=['730', 'North', 'Devon', 'Ave \xa0Helena,', 'MT', '59601'], tags=['Address']),
#  LabeledSentence(words=['1', 'Kirkland', 'St \xa0North', 'Attleboro,', 'MA', '02760'], tags=['Address']),
#  LabeledSentence(words=['59', 'Glen', 'Creek', 'Ave \xa0Hilliard,', 'OH', '43026'], tags=['Address']),
#  LabeledSentence(words=['792', 'Randall', 'Mill', 'Rd \xa0Hammonton,', 'NJ', '08037'], tags=['Address']),
#  LabeledSentence(words=['17', 'Garden', 'St \xa0Henderson,', 'KY', '42420'], tags=['Address']),
#  LabeledSentence(words=['88', 'Sussex', 'Ave \xa0Hampton,', 'VA', '23666'], tags=['Address']),
#  LabeledSentence(words=['72', 'North', 'Green', 'Street\xa0Ogden,', 'UT', '84404'], tags=['Address']),
#  LabeledSentence(words=['9481', 'Marconi', 'Ave \xa0Wasilla,', 'AK', '99654'], tags=['Address']),
#  LabeledSentence(words=['246', 'Redwood', 'Road\xa0Anchorage,', 'AK', '99504'], tags=['Address']),
#  LabeledSentence(words=['7929', 'North', 'Fulton', 'Ave \xa0Reynoldsburg,', 'OH', '43068'], tags=['Address']),
#  LabeledSentence(words=['7048', 'Lake', 'Forest', 'Drive\xa0Harrisonburg,', 'VA', '22801'], tags=['Address']),
#  LabeledSentence(words=['69', 'Church', 'St \xa0Victoria,', 'TX', '77904'], tags=['Address']),
#  LabeledSentence(words=['872', 'Lakeshore', 'Lane\xa0Charlotte,', 'NC', '28205'], tags=['Address']),
#  LabeledSentence(words=['820', 'Fawn', 'Street\xa0Gibsonia,', 'PA', '15044'], tags=['Address']),
#  LabeledSentence(words=['83', 'West', 'Dunbar', 'Avenue\xa0Park', 'Forest,', 'IL', '60466'], tags=['Address']),
#  LabeledSentence(words=['8072', 'Arlington', 'Rd \xa0Horn', 'Lake,', 'MS', '38637'], tags=['Address']),
#  LabeledSentence(words=['273', 'Dogwood', 'Street\xa0Minot,', 'ND', '58701'], tags=['Address']),
#  LabeledSentence(words=['857', 'Fawn', 'Ave \xa0Huntington,', 'NY', '11743'], tags=['Address']),
#  LabeledSentence(words=['15', 'Cedar', 'Swamp', 'Dr \xa0Mableton,', 'GA', '30126'], tags=['Address']),
#  LabeledSentence(words=['8581', 'N ', 'Corona', 'St \xa0Orange', 'Park,', 'FL', '32065'], tags=['Address']),
#  LabeledSentence(words=['954', 'Brown', 'St \xa0Wyoming,', 'MI', '49509'], tags=['Address']),
#  LabeledSentence(words=['68', 'Union', 'Circle\xa0Bolingbrook,', 'IL', '60440'], tags=['Address']),
#  LabeledSentence(words=['657', 'NE ', 'Pilgrim', 'St \xa0Akron,', 'OH', '44312'], tags=['Address']),
#  LabeledSentence(words=['9447', 'Bradford', 'Drive\xa0Saint', 'Cloud,', 'MN', '56301'], tags=['Address']),
#  LabeledSentence(words=['7682', 'Cemetery', 'Drive\xa0Goshen,', 'IN', '46526'], tags=['Address']),
#  LabeledSentence(words=['356', 'Surrey', 'Street\xa0Perkasie,', 'PA', '18944'], tags=['Address']),
#  LabeledSentence(words=['9678', 'Golden', 'Star', 'St \xa0Langhorne,', 'PA', '19047'], tags=['Address']),
#  LabeledSentence(words=['1', 'Pilgrim', 'Street\xa0Bismarck,', 'ND', '58501'], tags=['Address']),
#  LabeledSentence(words=['8', 'Walnutwood', 'St \xa0Wilmette,', 'IL', '60091'], tags=['Address']),
#  LabeledSentence(words=['9548', 'Mayfield', 'St \xa0North', 'Andover,', 'MA', '01845'], tags=['Address']),
# ...
#  LabeledSentence(words=['9232', 'North', 'Second', 'Street\xa0Newport', 'News,', 'VA', '23601'], tags=['Address']),
#  LabeledSentence(words=['568', 'Brown', 'Street\xa0Orange,', 'NJ', '07050'], tags=['Address']),
#  LabeledSentence(words=['42', 'Cedarwood', 'St \xa0Fairfield,', 'CT', '06824'], tags=['Address']),
#  LabeledSentence(words=['540', 'South', 'Plymouth', 'Drive\xa0Manchester', 'Township,', 'NJ', '08759'], tags=['Address']),
#  LabeledSentence(words=['781', 'Court', 'Street\xa0Port', 'Washington,', 'NY', '11050'], tags=['Address']),
#  LabeledSentence(words=['9600', 'N ', 'Cobblestone', 'Lane\xa0Mableton,', 'GA', '30126'], tags=['Address']),
#  LabeledSentence(words=['48', 'Selby', 'Dr \xa0Westlake,', 'OH', '44145'], tags=['Address']),
#  LabeledSentence(words=['98', 'Hillside', 'St \xa0Maplewood,', 'NJ', '07040'], tags=['Address']),
#  LabeledSentence(words=['290', 'Belmont', 'St \xa0Savage,', 'MN', '55378'], tags=['Address']),
#  LabeledSentence(words=['9386', 'Aspen', 'Dr \xa0Crofton,', 'MD', '21114'], tags=['Address']),
#  LabeledSentence(words=['790', 'Harrison', 'Drive\xa0Nicholasville,', 'KY', '40356'], tags=['Address']),
#  LabeledSentence(words=['7372', 'N ', 'Leatherwood', 'Drive\xa0York,', 'PA', '17402'], tags=['Address']),
#  LabeledSentence(words=['69', 'George', 'Lane\xa0Huntley,', 'IL', '60142'], tags=['Address']),
#  LabeledSentence(words=['646', 'Bedford', 'Drive\xa0Butte,', 'MT', '59701'], tags=['Address']),
#  LabeledSentence(words=['12', 'Marshall', 'Dr \xa0Durham,', 'NC', '27703'], tags=['Address']),
#  LabeledSentence(words=['152', 'Arch', 'Court\xa0Winder,', 'GA', '30680'], tags=['Address']),
#  LabeledSentence(words=['323', 'Windfall', 'Court\xa0Lebanon,', 'PA', '17042'], tags=['Address']),
#  LabeledSentence(words=['676', 'South', 'Green', 'Ave \xa0Stow,', 'OH', '44224'], tags=['Address']),
#  LabeledSentence(words=['78', 'Linden', 'Court\xa0Longwood,', 'FL', '32779'], tags=['Address']),
#  LabeledSentence(words=['11', 'King', 'Drive\xa0Neenah,', 'WI', '54956'], tags=['Address']),
#  LabeledSentence(words=['15', 'Tailwater', 'Street\xa0Teaneck,', 'NJ', '07666'], tags=['Address']),
#  LabeledSentence(words=['174', 'Somerset', 'Lane\xa0Oxford,', 'MS', '38655'], tags=['Address']),
#  LabeledSentence(words=['320', 'Ashley', 'Ave \xa0Canfield,', 'OH', '44406'], tags=['Address']),
#  LabeledSentence(words=['9616', 'S ', 'Pawnee', 'Street\xa0Wilmette,', 'IL', '60091'], tags=['Address']),
#  LabeledSentence(words=['425', 'Bowman', 'Ave \xa0Barberton,', 'OH', '44203'], tags=['Address']),
#  LabeledSentence(words=['7324', 'Canal', 'Street\xa0Owings', 'Mills,', 'MD', '21117'], tags=['Address']),
#  LabeledSentence(words=['94', 'Henry', 'Smith', 'Drive\xa0Faribault,', 'MN', '55021'], tags=['Address']),
#  LabeledSentence(words=['85', 'E ', 'Henry', 'Smith', 'Rd \xa0Smithtown,', 'NY', '11787'], tags=['Address']),
#  LabeledSentence(words=['7380', 'Lower', 'River', 'Street\xa0Chelmsford,', 'MA', '01824'], tags=['Address']),
#  LabeledSentence(words=['687', 'Pleasant', 'St \xa0Voorhees,', 'NJ', '08043'], tags=['Address']),
#  LabeledSentence(words=['658', 'Old', 'Military', 'Dr \xa0Roanoke,', 'VA', '24012'], tags=['Address']),
#  LabeledSentence(words=['7794', 'Sierra', 'St \xa0Baldwin,', 'NY', '11510'], tags=['Address']),
#  LabeledSentence(words=['3', 'North', 'Linden', 'St \xa0Elizabethtown,', 'PA', '17022'], tags=['Address']),
#  LabeledSentence(words=['693', 'East', 'Winchester', 'Drive\xa0Homestead,', 'FL', '33030'], tags=['Address']),
#  LabeledSentence(words=['929', 'N ', 'Canterbury', 'Lane\xa0Davenport,', 'IA', '52804'], tags=['Address']),
#  LabeledSentence(words=['9076', 'Shadow', 'Brook', 'Dr \xa0Torrington,', 'CT', '06790'], tags=['Address']),
#  LabeledSentence(words=['891', 'Market', 'Drive\xa0Wallingford,', 'CT', '06492'], tags=['Address']),
#  LabeledSentence(words=['248', 'Marconi', 'Avenue\xa0Westminster,', 'MD', '21157'], tags=['Address']),
#  LabeledSentence(words=['544', 'Hudson', 'St \xa0Doylestown,', 'PA', '18901'], tags=['Address']),
#  LabeledSentence(words=['70', 'E ', 'Helen', 'Lane\xa0Suite', '22\xa0'], tags=['Address']),
#  LabeledSentence(words=['Frederick,', 'MD', '21701451', 'South', 'Elmwood', 'Street\xa0'], tags=['Address']),
#  LabeledSentence(words=['Malvern,', 'PA', '19355534', 'Cobblestone', 'Dr \xa0'], tags=['Address']),
#  LabeledSentence(words=['Dekalb,', 'IL', '60115516', 'SW ', 'High', 'Point', 'St \xa0'], tags=['Address']),
#  LabeledSentence(words=['Tupelo,', 'MS', '38801472', 'Hall', 'Ave \xa0'], tags=['Address']),
#  LabeledSentence(words=['King', 'Of', 'Prussia,', 'PA', '19406364', 'East', 'Rockwell', 'Ave \xa0'], tags=['Address']),
#  LabeledSentence(words=['Mocksville,', 'NC', '27028690', 'North', 'Rd \xa0'], tags=['Address']),
#  LabeledSentence(words=['Littleton,', 'CO', '80123456', 'Arcadia', 'Street\xa0'], tags=['Address']),
#  LabeledSentence(words=['Severn,', 'MD', '21144613', 'East', 'Grand', 'St \xa0'], tags=['Address']),
#  LabeledSentence(words=['Hyde', 'Park,', 'MA', '021367', 'Somerset', 'Ave \xa0'], tags=['Address']),
#  LabeledSentence(words=['Rockaway,', 'NJ', '0786615', 'Redwood', 'Street\xa0'], tags=['Address']),
#  LabeledSentence(words=['Westland,', 'MI', '48185425', 'Walnutwood', 'Court\xa0'], tags=['Address']),
#  LabeledSentence(words=['Graham,', 'NC', '27253810', 'Briarwood', 'Court\xa0'], tags=['Address']),
#  LabeledSentence(words=['Apt', '52\xa0Ambler,', 'PA', '19002'], tags=['Address']),
#  LabeledSentence(words=['1', 'N ', 'Brown', 'Lane\xa0West', 'Orange,', 'NJ', '07052'], tags=['Address']),
#  LabeledSentence(words=['3', 'Harrison', 'Lane\xa0Nashville,', 'TN', '37205'], tags=['Address']),
#  LabeledSentence(words=['6', 'Oklahoma', 'Ave \xa0North', 'Ridgeville,', 'OH', '44039'], tags=['Address']),
#  LabeledSentence(words=['8927', 'Crescent', 'Dr \xa0West', 'Roxbury,', 'MA', '02132'], tags=['Address']),
#  LabeledSentence(words=['7756', 'Rockwell', 'Street\xa0Depew,', 'NY', '14043'], tags=['Address']),
#  LabeledSentence(words=['913', 'High', 'Ridge', 'St \xa0Middleton,', 'WI', '53562'], tags=['Address']),
#  LabeledSentence(words=['7333', 'Lexington', 'St \xa0Stoughton,', 'MA', '02072'], tags=['Address']),
#  LabeledSentence(words=['123', 'Studebaker', 'Ave \xa0Brandon,', 'FL', '33510'], tags=['Address']),
#  LabeledSentence(words=['590', 'Arnold', 'St \xa0New', 'Baltimore,', 'MI', '48047'], tags=['Address']),
#  LabeledSentence(words=['73', 'Gregory', 'Ave \xa0Rockledge,', 'FL', '32955'], tags=['Address']),
#  LabeledSentence(words=['933', 'Paris', 'Hill', 'Ave \xa0Hudson,', 'NH', '03051'], tags=['Address']),
#  LabeledSentence(words=['18', 'South', 'Shady', 'St \xa0Easley,', 'SC', '29640'], tags=['Address']),
#  LabeledSentence(words=['67', 'East', 'Alton', 'Rd \xa0Staten', 'Island,', 'NY', '10301'], tags=['Address']),
#  LabeledSentence(words=['874', 'Plumb', 'Branch', 'Road\xa0Monroe', 'Township,', 'NJ', '08831'], tags=['Address']),
#  LabeledSentence(words=['30', 'Orange', 'Ave \xa0Union', 'City,', 'NJ', '07087'], tags=['Address']),
#  LabeledSentence(words=['9357', 'Durham', 'Circle\xa0Warren,', 'MI', '48089'], tags=['Address']),
#  LabeledSentence(words=['9469', 'Cross', 'Dr \xa0Marietta,', 'GA', '30008'], tags=['Address']),
#  LabeledSentence(words=['1', 'Windfall', 'Lane\xa0Bridgeport,', 'CT', '06606'], tags=['Address']),
#  LabeledSentence(words=['8031', 'Hawthorne', 'Ave \xa0Patchogue,', 'NY', '11772'], tags=['Address']),
#  LabeledSentence(words=['510', 'SW ', 'Euclid', 'Ave \xa0Sheboygan,', 'WI', '53081'], tags=['Address']),
#  LabeledSentence(words=['8223', 'Country', 'Club', 'Drive\xa0Covington,', 'GA', '30014'], tags=['Address']),
#  LabeledSentence(words=['8494', 'N ', 'Cypress', 'St \xa0Dracut,', 'MA', '01826'], tags=['Address']),
#  LabeledSentence(words=['644', 'Piper', 'Avenue\xa0Rolling', 'Meadows,', 'IL', '60008'], tags=['Address']),
#  LabeledSentence(words=['8578', 'Shore', 'Street\xa0Dedham,', 'MA', '02026'], tags=['Address']),
#  LabeledSentence(words=['9792', 'Rosewood', 'Street\xa0Newnan,', 'GA', '30263'], tags=['Address']),
#  LabeledSentence(words=['9137', 'Fordham', 'St \xa0Libertyville,', 'IL', '60048'], tags=['Address']),
#  LabeledSentence(words=['405', 'Ivy', 'Ave \xa0Staunton,', 'VA', '24401'], tags=['Address']),
#  LabeledSentence(words=['139', 'Leatherwood', 'Street\xa0Riverview,', 'FL', '33569'], tags=['Address']),
#  LabeledSentence(words=['8884', 'East', 'St', 'Paul', 'Rd \xa0Oklahoma', 'City,', 'OK', '73112'], tags=['Address']),
#  LabeledSentence(words=['8940', 'Gainsway', 'Street\xa0Royersford,', 'PA', '19468'], tags=['Address']),
#  LabeledSentence(words=['733', 'S ', 'Jockey', 'Hollow', 'Drive\xa0Lady', 'Lake,', 'FL', '32159'], tags=['Address']),
#  LabeledSentence(words=['38', 'Roosevelt', 'Rd \xa0Front', 'Royal,', 'VA', '22630'], tags=['Address']),
#  LabeledSentence(words=['526', 'Canterbury', 'St \xa0Hanover,', 'PA', '17331'], tags=['Address']),
#  LabeledSentence(words=['9915', 'Ramblewood', 'St \xa0Newington,', 'CT', '06111'], tags=['Address']),
#  LabeledSentence(words=['36', 'Maiden', 'Drive\xa0Bardstown,', 'KY', '40004'], tags=['Address']),
#  LabeledSentence(words=['141', 'Wintergreen', 'Avenue\xa0Summerville,', 'SC', '29483'], tags=['Address']),
#  LabeledSentence(words=['501', 'Southampton', 'St \xa0Richmond,', 'VA', '23223'], tags=['Address']),
#  LabeledSentence(words=['9484', 'Saxon', 'Ave \xa0Westbury,', 'NY', '11590'], tags=['Address']),
#  LabeledSentence(words=['732', 'Airport', 'Street\xa0Hartford,', 'CT', '06106'], tags=['Address']),
#  LabeledSentence(words=['8973', 'Bedford', 'Lane\xa0Brighton,', 'MA', '02135'], tags=['Address']),
#  LabeledSentence(words=['7636', 'Bay', 'Meadows', 'Lane\xa0Stone', 'Mountain,', 'GA', '30083'], tags=['Address']),
#  LabeledSentence(words=['87', 'South', 'Vale', 'St \xa0Sterling', 'Heights,', 'MI', '48310'], tags=['Address']),
#  LabeledSentence(words=['886', 'East', 'Brewery', 'Lane\xa0Dundalk,', 'MD', '21222'], tags=['Address']),
#  LabeledSentence(words=['210', 'Glen', 'Ridge', 'Drive\xa0Cheshire,', 'CT', '06410'], tags=['Address']),
#  LabeledSentence(words=['7256', 'Strawberry', 'Ave \xa0Geneva,', 'IL', '60134'], tags=['Address']),
#  LabeledSentence(words=['94', 'Wintergreen', 'Ave \xa0Suffolk,', 'VA', '23434'], tags=['Address']),
#  LabeledSentence(words=['812', 'Applegate', 'Ave \xa0New', 'York,', 'NY', '10002'], tags=['Address']),
#  LabeledSentence(words=['7340', 'Foster', 'Drive\xa0Goldsboro,', 'NC', '27530'], tags=['Address']),
#  LabeledSentence(words=['854', 'Peg', 'Shop', 'Street\xa0Prattville,', 'AL', '36067'], tags=['Address']),
#  LabeledSentence(words=['821', 'S ', 'Livingston', 'St \xa0Columbia,', 'MD', '21044'], tags=['Address']),
#  LabeledSentence(words=['297', 'Rosewood', 'Court\xa0Yorktown,', 'VA', '23693'], tags=['Address']),
#  LabeledSentence(words=['486', 'Lake', 'View', 'St \xa0Saint', 'Louis,', 'MO', '63109'], tags=['Address']),
#  LabeledSentence(words=['123', 'Arch', 'Ave \xa0Carpentersville,', 'IL', '60110'], tags=['Address']),
#  LabeledSentence(words=['62', 'Hilldale', 'Drive\xa0Southington,', 'CT', '06489'], tags=['Address']),
#  LabeledSentence(words=['238', 'Canterbury', 'Ave \xa0Ottawa,', 'IL', '61350'], tags=['Address']),
#  LabeledSentence(words=['9850', 'White', 'Drive\xa0Independence,', 'KY', '41051'], tags=['Address']),
#  LabeledSentence(words=['964', 'Edgewood', 'Drive\xa0Bloomington,', 'IN', '47401'], tags=['Address']),
#  LabeledSentence(words=['7623', 'Prospect', 'Ave \xa0Elmont,', 'NY', '11003'], tags=['Address']),
#  LabeledSentence(words=['22', 'Linda', 'Court\xa0Galloway,', 'OH', '43119'], tags=['Address']),
#  LabeledSentence(words=['521B', 'Arnold', 'Road\xa0Floral', 'Park,', 'NY', '11001'], tags=['Address']),
#  LabeledSentence(words=['9363', 'James', 'Drive\xa0Bloomfield,', 'NJ', '07003'], tags=['Address']),
#  LabeledSentence(words=['9375', 'Pineknoll', 'Lane\xa0Scarsdale,', 'NY', '10583'], tags=['Address']),
#  LabeledSentence(words=['892', 'Eagle', 'Dr \xa0Woodstock,', 'GA', '30188'], tags=['Address']),
#  LabeledSentence(words=['999', 'Country', 'Ave \xa0Hermitage,', 'TN', '37076'], tags=['Address']),
#  LabeledSentence(words=['12', 'Fulton', 'Ave \xa0Anaheim,', 'CA', '92806'], tags=['Address']),
#  LabeledSentence(words=['99', 'Garden', 'Ave \xa0Cantonment,', 'FL', '32533'], tags=['Address']),
#  LabeledSentence(words=['53', 'Birchpond', 'St \xa0Bronx,', 'NY', '10451'], tags=['Address']),
#  LabeledSentence(words=['9351', 'Hill', 'Field', 'Ave \xa0North', 'Brunswick,', 'NJ', '08902'], tags=['Address']),
#  LabeledSentence(words=['460', 'Chapel', 'Drive\xa0Knoxville,', 'TN', '37918'], tags=['Address']),
#  LabeledSentence(words=['524', 'Summit', 'St \xa0Poughkeepsie,', 'NY', '12601'], tags=['Address']),
#  LabeledSentence(words=['91', 'Winchester', 'Dr \xa0Mount', 'Laurel,', 'NJ', '08054'], tags=['Address']),
#  LabeledSentence(words=['336', 'W ', 'Wentworth', 'Road\xa0Perth', 'Amboy,', 'NJ', '08861'], tags=['Address']),
#  LabeledSentence(words=['9582', 'Broad', 'St \xa0Flint,', 'MI', '48504'], tags=['Address']),
#  LabeledSentence(words=['9325', 'Applegate', 'St \xa0Tucson,', 'AZ', '85718'], tags=['Address']),
#  LabeledSentence(words=['71', 'Lexington', 'Avenue\xa0Oswego,', 'NY', '13126'], tags=['Address']),
#  LabeledSentence(words=['480', 'North', 'Rose', 'Dr \xa0Glenside,', 'PA', '19038'], tags=['Address']),
#  LabeledSentence(words=['327', 'San', 'Carlos', 'Ave \xa0Grand', 'Rapids,', 'MI', '49503'], tags=['Address']),
#  LabeledSentence(words=['842', 'Poor', 'House', 'Dr \xa0Simpsonville,', 'SC', '29680'], tags=['Address']),
#  LabeledSentence(words=['9157', 'Schoolhouse', 'Dr \xa0Lockport,', 'NY', '14094'], tags=['Address']),
#  LabeledSentence(words=['8928', 'Westport', 'Drive\xa0Janesville,', 'WI', '53546'], tags=['Address']),
#  LabeledSentence(words=['8344', 'Myrtle', 'Ave \xa0Mishawaka,', 'IN', '46544'], tags=['Address']),
#  LabeledSentence(words=['266', 'Gartner', 'Dr \xa0Lincoln', 'Park,', 'MI', '48146'], tags=['Address']),
#  LabeledSentence(words=['9503', 'W ', 'Pennington', 'St \xa0Fayetteville,', 'NC', '28303'], tags=['Address']),
#  LabeledSentence(words=['7319', 'Chestnut', 'Street\xa0Matthews,', 'NC', '28104'], tags=['Address']),
#  LabeledSentence(words=['9573', 'Central', 'Lane\xa0Revere,', 'MA', '02151'], tags=['Address']),
#  LabeledSentence(words=['188', 'Forest', 'Street\xa0Coraopolis,', 'PA', '15108'], tags=['Address']),
#  LabeledSentence(words=['588', 'Fawn', 'Street\xa0Traverse', 'City,', 'MI', '49684'], tags=['Address']),
#  LabeledSentence(words=['405', 'Pheasant', 'Lane\xa0Mcallen,', 'TX', '78501'], tags=['Address']),
#  LabeledSentence(words=['30', 'Tanglewood', 'St \xa0Marquette,', 'MI', '49855'], tags=['Address']),
#  LabeledSentence(words=['64', 'Front', 'St \xa0Paramus,', 'NJ', '07652'], tags=['Address']),
#  LabeledSentence(words=['7643', 'River', 'St \xa0Levittown,', 'NY', '11756'], tags=['Address']),
#  LabeledSentence(words=['91', 'Branch', 'Lane\xa0Hillsborough,', 'NJ', '08844'], tags=['Address']),
#  LabeledSentence(words=['1', 'Newport', 'St \xa0Casselberry,', 'FL', '32707'], tags=['Address']),
#  LabeledSentence(words=['8', 'N ', 'Trout', 'Dr \xa0Hephzibah,', 'GA', '30815'], tags=['Address']),
#  LabeledSentence(words=['8645', 'Ocean', 'Avenue\xa0Far', 'Rockaway,', 'NY', '11691'], tags=['Address']),
#  LabeledSentence(words=['57', 'Rock', 'Maple', 'St \xa0Panama', 'City,', 'FL', '32404'], tags=['Address']),
#  LabeledSentence(words=['82', 'Rockledge', 'Dr \xa0Cedar', 'Rapids,', 'IA', '52402'], tags=['Address']),
#  LabeledSentence(words=['12', 'Shub', 'Farm', 'Drive\xa0Leesburg,', 'VA', '20175'], tags=['Address']),
#  LabeledSentence(words=['8743', 'Cypress', 'St \xa0Clifton', 'Park,', 'NY', '12065'], tags=['Address']),
#  LabeledSentence(words=['9358', 'Lakeview', 'St \xa0Santa', 'Cruz,', 'CA', '95060'], tags=['Address']),
#  LabeledSentence(words=['9313', 'Lyme', 'Lane\xa0Council', 'Bluffs,', 'IA', '51501'], tags=['Address']),
#  LabeledSentence(words=['521', 'Acacia', 'Drive\xa0Glen', 'Allen,', 'VA', '23059'], tags=['Address']),
#  LabeledSentence(words=['543', 'Greenrose', 'St \xa0Utica,', 'NY', '13501'], tags=['Address']),
#  ...]

# %%
model = Doc2Vec(sentences, min_count=1, window=100, size=50, workers=7, iter = 20)
print(sentences[1:4])
print('vocab done*********************')
model.train(sentences, epochs=model.iter, total_examples=model.corpus_count)
model.save('./new_imdb_withoutID_medium.d2v')

	# MODEL PARAMETERS
# Out:
# C:\Anaconda3\lib\site-packages\gensim\models\doc2vec.py:576: UserWarning: The parameter `iter` is deprecated, will be removed in 4.0.0, use `epochs` instead.
#   warnings.warn("The parameter `iter` is deprecated, will be removed in 4.0.0, use `epochs` instead.")
# C:\Anaconda3\lib\site-packages\gensim\models\doc2vec.py:580: UserWarning: The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.
#   warnings.warn("The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.")
# 2019-04-07 12:21:08,072 : WARNING : consider setting layer size to a multiple of 4 for greater performance
# 2019-04-07 12:21:08,074 : INFO : collecting all words and their counts
# 2019-04-07 12:21:08,075 : INFO : PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# 2019-04-07 12:21:08,164 : INFO : PROGRESS: at example #10000, processed 151515 words (1724942/s), 23934 word types, 3 tags
# 2019-04-07 12:21:08,178 : INFO : collected 26593 word types and 3 unique tags from a corpus of 11249 examples and 199742 words
# 2019-04-07 12:21:08,179 : INFO : Loading a fresh vocabulary
# 2019-04-07 12:21:08,272 : INFO : effective_min_count=1 retains 26593 unique words (100% of original 26593, drops 0)
# 2019-04-07 12:21:08,273 : INFO : effective_min_count=1 leaves 199742 word corpus (100% of original 199742, drops 0)
# 2019-04-07 12:21:08,334 : INFO : deleting the raw counts dictionary of 26593 items
# 2019-04-07 12:21:08,336 : INFO : sample=0.001 downsamples 28 most-common words
# 2019-04-07 12:21:08,336 : INFO : downsampling leaves estimated 158420 word corpus (79.3% of prior 199742)
# 2019-04-07 12:21:08,400 : INFO : estimated required memory for 26593 words and 50 dimensions: 23934900 bytes
# 2019-04-07 12:21:08,401 : INFO : resetting layer weights
# 2019-04-07 12:21:08,656 : INFO : training model with 7 workers on 26593 vocabulary and 50 features, using sg=0 hs=0 sample=0.001 negative=5 window=100
# 2019-04-07 12:21:09,397 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-07 12:21:09,398 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-07 12:21:09,417 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-07 12:21:09,439 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-07 12:21:09,447 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-07 12:21:09,449 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-07 12:21:09,460 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-07 12:21:09,461 : INFO : EPOCH - 1 : training on 199742 raw words (169607 effective words) took 0.8s, 215388 effective words/s
# 2019-04-07 12:21:10,153 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-07 12:21:10,173 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-07 12:21:10,190 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-07 12:21:10,209 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-07 12:21:10,213 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-07 12:21:10,221 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-07 12:21:10,222 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-07 12:21:10,223 : INFO : EPOCH - 2 : training on 199742 raw words (169548 effective words) took 0.7s, 226250 effective words/s
# 2019-04-07 12:21:10,949 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-07 12:21:10,963 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-07 12:21:10,983 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-07 12:21:11,000 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-07 12:21:11,006 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-07 12:21:11,008 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-07 12:21:11,010 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-07 12:21:11,011 : INFO : EPOCH - 3 : training on 199742 raw words (169661 effective words) took 0.8s, 217990 effective words/s
# 2019-04-07 12:21:11,665 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-07 12:21:11,668 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-07 12:21:11,703 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-07 12:21:11,712 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-07 12:21:11,716 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-07 12:21:11,721 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-07 12:21:11,723 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-07 12:21:11,724 : INFO : EPOCH - 4 : training on 199742 raw words (169665 effective words) took 0.7s, 240080 effective words/s
# 2019-04-07 12:21:12,376 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-07 12:21:12,378 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-07 12:21:12,418 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-07 12:21:12,420 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-07 12:21:12,429 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-07 12:21:12,432 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-07 12:21:12,440 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-07 12:21:12,440 : INFO : EPOCH - 5 : training on 199742 raw words (169723 effective words) took 0.7s, 240340 effective words/s
# 2019-04-07 12:21:13,093 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-07 12:21:13,097 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-07 12:21:13,138 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-07 12:21:13,142 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-07 12:21:13,150 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-07 12:21:13,154 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-07 12:21:13,155 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-07 12:21:13,156 : INFO : EPOCH - 6 : training on 199742 raw words (169719 effective words) took 0.7s, 240241 effective words/s
# 2019-04-07 12:21:13,812 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-07 12:21:13,818 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-07 12:21:13,853 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-07 12:21:13,868 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-07 12:21:13,871 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-07 12:21:13,872 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-07 12:21:13,876 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-07 12:21:13,877 : INFO : EPOCH - 7 : training on 199742 raw words (169633 effective words) took 0.7s, 239209 effective words/s
# 2019-04-07 12:21:14,567 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-07 12:21:14,571 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-07 12:21:14,615 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-07 12:21:14,621 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-07 12:21:14,627 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-07 12:21:14,633 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-07 12:21:14,639 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-07 12:21:14,639 : INFO : EPOCH - 8 : training on 199742 raw words (169764 effective words) took 0.7s, 226376 effective words/s
# 2019-04-07 12:21:15,329 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-07 12:21:15,335 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-07 12:21:15,369 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-07 12:21:15,381 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-07 12:21:15,383 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-07 12:21:15,386 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-07 12:21:15,390 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-07 12:21:15,391 : INFO : EPOCH - 9 : training on 199742 raw words (169615 effective words) took 0.7s, 228688 effective words/s
# 2019-04-07 12:21:16,072 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-07 12:21:16,078 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-07 12:21:16,113 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-07 12:21:16,115 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-07 12:21:16,123 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-07 12:21:16,126 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-07 12:21:16,127 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-07 12:21:16,128 : INFO : EPOCH - 10 : training on 199742 raw words (169631 effective words) took 0.7s, 232371 effective words/s
# 2019-04-07 12:21:16,822 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-07 12:21:16,840 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-07 12:21:16,873 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-07 12:21:16,890 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-07 12:21:16,900 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-07 12:21:16,904 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-07 12:21:16,906 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-07 12:21:16,907 : INFO : EPOCH - 11 : training on 199742 raw words (169767 effective words) took 0.8s, 220719 effective words/s
# 2019-04-07 12:21:17,568 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-07 12:21:17,583 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-07 12:21:17,615 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-07 12:21:17,625 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-07 12:21:17,627 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-07 12:21:17,629 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-07 12:21:17,633 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-07 12:21:17,634 : INFO : EPOCH - 12 : training on 199742 raw words (169766 effective words) took 0.7s, 236698 effective words/s
# 2019-04-07 12:21:18,304 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-07 12:21:18,310 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-07 12:21:18,354 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-07 12:21:18,360 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-07 12:21:18,364 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-07 12:21:18,367 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-07 12:21:18,369 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-07 12:21:18,369 : INFO : EPOCH - 13 : training on 199742 raw words (169582 effective words) took 0.7s, 233144 effective words/s
# 2019-04-07 12:21:19,058 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-07 12:21:19,079 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-07 12:21:19,112 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-07 12:21:19,114 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-07 12:21:19,119 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-07 12:21:19,124 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-07 12:21:19,129 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-07 12:21:19,130 : INFO : EPOCH - 14 : training on 199742 raw words (169678 effective words) took 0.8s, 226106 effective words/s
# 2019-04-07 12:21:19,795 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-07 12:21:19,802 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-07 12:21:19,837 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-07 12:21:19,847 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-07 12:21:19,852 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-07 12:21:19,856 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-07 12:21:19,858 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-07 12:21:19,858 : INFO : EPOCH - 15 : training on 199742 raw words (169718 effective words) took 0.7s, 236894 effective words/s
# 2019-04-07 12:21:20,520 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-07 12:21:20,528 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-07 12:21:20,564 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-07 12:21:20,569 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-07 12:21:20,576 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-07 12:21:20,581 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-07 12:21:20,585 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-07 12:21:20,585 : INFO : EPOCH - 16 : training on 199742 raw words (169663 effective words) took 0.7s, 236289 effective words/s
# 2019-04-07 12:21:21,256 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-07 12:21:21,264 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-07 12:21:21,309 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-07 12:21:21,311 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-07 12:21:21,315 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-07 12:21:21,320 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-07 12:21:21,323 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-07 12:21:21,324 : INFO : EPOCH - 17 : training on 199742 raw words (169778 effective words) took 0.7s, 233331 effective words/s
# 2019-04-07 12:21:21,976 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-07 12:21:21,989 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-07 12:21:22,019 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-07 12:21:22,027 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-07 12:21:22,032 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-07 12:21:22,035 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-07 12:21:22,043 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-07 12:21:22,044 : INFO : EPOCH - 18 : training on 199742 raw words (169648 effective words) took 0.7s, 240827 effective words/s
# 2019-04-07 12:21:22,744 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-07 12:21:22,749 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-07 12:21:22,787 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-07 12:21:22,788 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-07 12:21:22,791 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-07 12:21:22,796 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-07 12:21:22,803 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-07 12:21:22,803 : INFO : EPOCH - 19 : training on 199742 raw words (169627 effective words) took 0.7s, 227860 effective words/s
# 2019-04-07 12:21:23,495 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-07 12:21:23,500 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-07 12:21:23,523 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-07 12:21:23,526 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-07 12:21:23,536 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-07 12:21:23,540 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-07 12:21:23,549 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-07 12:21:23,550 : INFO : EPOCH - 20 : training on 199742 raw words (169491 effective words) took 0.7s, 231566 effective words/s
# 2019-04-07 12:21:23,551 : INFO : training on a 3994840 raw words (3393284 effective words) took 14.9s, 227829 effective words/s
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: Call to deprecated `iter` (Attribute will be removed in 4.0.0, use self.epochs instead).
#   after removing the cwd from sys.path.
# 2019-04-07 12:21:23,556 : WARNING : Effective 'alpha' higher than previous training cycles
# 2019-04-07 12:21:23,557 : INFO : training model with 7 workers on 26593 vocabulary and 50 features, using sg=0 hs=0 sample=0.001 negative=5 window=100
# [LabeledSentence(words=['932', 'Bishop', 'St \xa0Billerica,', 'MA', '01821'], tags=['Address']), LabeledSentence(words=['7906', 'Silver', 'Spear', 'Road\xa0Davison,', 'MI', '48423'], tags=['Address']), LabeledSentence(words=['9739', 'Acacia', 'Lane\xa0Beaver', 'Falls,', 'PA', '15010'], tags=['Address'])]
# vocab done*********************
# 2019-04-07 12:21:24,287 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-07 12:21:24,297 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-07 12:21:24,323 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-07 12:21:24,333 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-07 12:21:24,338 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-07 12:21:24,343 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-07 12:21:24,349 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-07 12:21:24,350 : INFO : EPOCH - 1 : training on 199742 raw words (169874 effective words) took 0.8s, 217036 effective words/s
# 2019-04-07 12:21:25,014 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-07 12:21:25,026 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-07 12:21:25,061 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-07 12:21:25,067 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-07 12:21:25,074 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-07 12:21:25,075 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-07 12:21:25,078 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-07 12:21:25,079 : INFO : EPOCH - 2 : training on 199742 raw words (169900 effective words) took 0.7s, 236125 effective words/s
# 2019-04-07 12:21:25,744 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-07 12:21:25,759 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-07 12:21:25,789 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-07 12:21:25,797 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-07 12:21:25,800 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-07 12:21:25,806 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-07 12:21:25,807 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-07 12:21:25,808 : INFO : EPOCH - 3 : training on 199742 raw words (169712 effective words) took 0.7s, 235852 effective words/s
# 2019-04-07 12:21:26,476 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-07 12:21:26,488 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-07 12:21:26,520 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-07 12:21:26,528 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-07 12:21:26,538 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-07 12:21:26,540 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-07 12:21:26,543 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-07 12:21:26,543 : INFO : EPOCH - 4 : training on 199742 raw words (169703 effective words) took 0.7s, 235372 effective words/s
# 2019-04-07 12:21:27,204 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-07 12:21:27,233 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-07 12:21:27,270 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-07 12:21:27,274 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-07 12:21:27,279 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-07 12:21:27,286 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-07 12:21:27,287 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-07 12:21:27,288 : INFO : EPOCH - 5 : training on 199742 raw words (169552 effective words) took 0.7s, 230761 effective words/s
# 2019-04-07 12:21:27,943 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-07 12:21:27,957 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-07 12:21:27,986 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-07 12:21:27,988 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-07 12:21:27,995 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-07 12:21:27,999 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-07 12:21:28,007 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-07 12:21:28,007 : INFO : EPOCH - 6 : training on 199742 raw words (169690 effective words) took 0.7s, 238941 effective words/s
# 2019-04-07 12:21:28,679 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-07 12:21:28,690 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-07 12:21:28,730 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-07 12:21:28,738 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-07 12:21:28,745 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-07 12:21:28,750 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-07 12:21:28,751 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-07 12:21:28,752 : INFO : EPOCH - 7 : training on 199742 raw words (169720 effective words) took 0.7s, 230982 effective words/s
# 2019-04-07 12:21:29,437 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-07 12:21:29,458 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-07 12:21:29,500 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-07 12:21:29,503 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-07 12:21:29,508 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-07 12:21:29,513 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-07 12:21:29,515 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-07 12:21:29,516 : INFO : EPOCH - 8 : training on 199742 raw words (169591 effective words) took 0.8s, 225469 effective words/s
# 2019-04-07 12:21:30,164 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-07 12:21:30,181 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-07 12:21:30,226 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-07 12:21:30,228 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-07 12:21:30,234 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-07 12:21:30,238 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-07 12:21:30,243 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-07 12:21:30,244 : INFO : EPOCH - 9 : training on 199742 raw words (169694 effective words) took 0.7s, 235842 effective words/s
# 2019-04-07 12:21:30,915 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-07 12:21:30,920 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-07 12:21:30,954 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-07 12:21:30,961 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-07 12:21:30,968 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-07 12:21:30,972 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-07 12:21:30,974 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-07 12:21:30,975 : INFO : EPOCH - 10 : training on 199742 raw words (169606 effective words) took 0.7s, 235016 effective words/s
# 2019-04-07 12:21:31,691 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-07 12:21:31,707 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-07 12:21:31,740 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-07 12:21:31,748 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-07 12:21:31,755 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-07 12:21:31,759 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-07 12:21:31,762 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-07 12:21:31,763 : INFO : EPOCH - 11 : training on 199742 raw words (169581 effective words) took 0.8s, 217778 effective words/s
# 2019-04-07 12:21:32,533 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-07 12:21:32,553 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-07 12:21:32,608 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-07 12:21:32,622 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-07 12:21:32,631 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-07 12:21:32,637 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-07 12:21:32,643 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-07 12:21:32,644 : INFO : EPOCH - 12 : training on 199742 raw words (169775 effective words) took 0.9s, 195539 effective words/s
# 2019-04-07 12:21:33,469 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-07 12:21:33,474 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-07 12:21:33,513 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-07 12:21:33,525 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-07 12:21:33,528 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-07 12:21:33,533 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-07 12:21:33,534 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-07 12:21:33,535 : INFO : EPOCH - 13 : training on 199742 raw words (169809 effective words) took 0.9s, 194992 effective words/s
# 2019-04-07 12:21:34,398 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-07 12:21:34,401 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-07 12:21:34,433 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-07 12:21:34,441 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-07 12:21:34,446 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-07 12:21:34,453 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-07 12:21:34,458 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-07 12:21:34,459 : INFO : EPOCH - 14 : training on 199742 raw words (169762 effective words) took 0.9s, 186843 effective words/s
# 2019-04-07 12:21:35,181 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-07 12:21:35,190 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-07 12:21:35,235 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-07 12:21:35,239 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-07 12:21:35,241 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-07 12:21:35,247 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-07 12:21:35,249 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-07 12:21:35,250 : INFO : EPOCH - 15 : training on 199742 raw words (169513 effective words) took 0.8s, 216849 effective words/s
# 2019-04-07 12:21:35,948 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-07 12:21:35,957 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-07 12:21:35,987 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-07 12:21:35,991 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-07 12:21:36,001 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-07 12:21:36,006 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-07 12:21:36,014 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-07 12:21:36,015 : INFO : EPOCH - 16 : training on 199742 raw words (169689 effective words) took 0.8s, 225045 effective words/s
# 2019-04-07 12:21:36,690 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-07 12:21:36,696 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-07 12:21:36,736 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-07 12:21:36,741 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-07 12:21:36,749 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-07 12:21:36,750 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-07 12:21:36,755 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-07 12:21:36,755 : INFO : EPOCH - 17 : training on 199742 raw words (169847 effective words) took 0.7s, 232583 effective words/s
# 2019-04-07 12:21:37,476 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-07 12:21:37,478 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-07 12:21:37,518 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-07 12:21:37,520 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-07 12:21:37,522 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-07 12:21:37,531 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-07 12:21:37,540 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-07 12:21:37,540 : INFO : EPOCH - 18 : training on 199742 raw words (169786 effective words) took 0.8s, 219290 effective words/s
# 2019-04-07 12:21:38,269 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-07 12:21:38,286 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-07 12:21:38,313 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-07 12:21:38,317 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-07 12:21:38,330 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-07 12:21:38,353 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-07 12:21:38,361 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-07 12:21:38,363 : INFO : EPOCH - 19 : training on 199742 raw words (169567 effective words) took 0.8s, 208295 effective words/s
# 2019-04-07 12:21:39,102 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-07 12:21:39,127 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-07 12:21:39,160 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-07 12:21:39,165 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-07 12:21:39,169 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-07 12:21:39,174 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-07 12:21:39,175 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-07 12:21:39,176 : INFO : EPOCH - 20 : training on 199742 raw words (169640 effective words) took 0.8s, 213997 effective words/s
# 2019-04-07 12:21:39,176 : INFO : training on a 3994840 raw words (3394011 effective words) took 15.6s, 217314 effective words/s
# 2019-04-07 12:21:39,178 : INFO : saving Doc2Vec object under ./new_imdb_withoutID_medium.d2v, separately None
# 2019-04-07 12:21:39,324 : INFO : saved ./new_imdb_withoutID_medium.d2v
