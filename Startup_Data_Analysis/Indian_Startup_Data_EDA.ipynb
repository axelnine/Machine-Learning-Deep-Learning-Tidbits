# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
startup_data = pd.read_csv("C:\\Users\\PRESHAH\\Desktop\\startup_funding.csv")

# %%
startup_data.head()
# Out:
#    SNo        Date   StartupName   IndustryVertical  \
# 0    0  01/08/2017      TouchKin         Technology
# 1    1  02/08/2017       Ethinos         Technology
# 2    2  02/08/2017  Leverage Edu  Consumer Internet
# 3    3  02/08/2017          Zepo  Consumer Internet
# 4    4  02/08/2017  Click2Clinic  Consumer Internet
#
#                                      SubVertical CityLocation  \
# 0                       Predictive Care Platform    Bangalore
# 1                       Digital Marketing Agency       Mumbai
# 2  Online platform for Higher Education Services    New Delhi
# 3                         DIY Ecommerce platform       Mumbai
# 4                  healthcare service aggregator    Hyderabad
#
#                                        InvestorsName  InvestmentType  \
# 0                                        Kae Capital  Private Equity
# 1                         Triton Investment Advisors  Private Equity
# ...

# %%
startup_data.describe()
# Out:
#                SNo
# count  2372.000000
# mean   1185.500000
# std     684.881742
# min       0.000000
# 25%     592.750000
# 50%    1185.500000
# 75%    1778.250000
# max    2371.000000

# %%
def  get_missing_values(data):
    
    """
    Function to calculate summary statistics of the data
    
    Input:
    
    data: dataframe for which summary statistics is needed.
    
    Output:
    
    Dataframe with summary statistics
    """
    #Calculate summary statistics of the data
    missing_values = pd.isnull(data).sum(axis=0)


    #Print the summary statistics
    summary = pd.concat([missing_values],axis=1)
    summary.columns = ['missing values']
    return summary

# %%
get_missing_values(startup_data)
# Out:
#                   missing values
# SNo                            0
# Date                           0
# StartupName                    0
# IndustryVertical             171
# SubVertical                  936
# CityLocation                 179
# InvestorsName                  8
# InvestmentType                 1
# AmountInUSD                  847
# Remarks                     1953

# %%
startup_data.groupby('CityLocation').count().head()
# Out:
#                        SNo  Date  StartupName  IndustryVertical  SubVertical  \
# CityLocation
# Agra                     2     2            2                 2            2
# Ahmedabad               35    35           35                35           25
# Bangalore              627   627          627               627          427
# Bangalore / Palo Alto    1     1            1                 1            0
# Bangalore / SFO          2     2            2                 2            1
#
#                        InvestorsName  InvestmentType  AmountInUSD  Remarks
# CityLocation
# Agra                               2               2            0        0
# Ahmedabad                         35              35           25        2
# Bangalore                        626             627          405       98
# Bangalore / Palo Alto              1               1            1        0
# Bangalore / SFO                    2               2            2        0

# %%
startup_data.groupby('InvestorsName').count().head()
# Out:
#                                                     SNo  Date  StartupName  \
# InvestorsName
# 1Crowd                                                1     1            1
# 1Crowd (through crowd funding)                        1     1            1
# 1Crowd (through crowdfunding)                         1     1            1
# 1Crowd, Eureka Forbes Ltd, Shapoorji Pallonji &...    1     1            1
# 3 undisclosed HNIs                                    1     1            1
#
#                                                     IndustryVertical  \
# InvestorsName
# 1Crowd                                                             1
# 1Crowd (through crowd funding)                                     1
# 1Crowd (through crowdfunding)                                      1
# 1Crowd, Eureka Forbes Ltd, Shapoorji Pallonji &...                 1
# 3 undisclosed HNIs                                                 1
#
# ...
